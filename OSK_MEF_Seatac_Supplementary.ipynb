# %% [markdown]
# <a href="https://colab.research.google.com/github/gongx030/seatac_manuscript/blob/main/OSK_MEF_Seatac_Supplementary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Examining nucleosomal changes of OSK motifs in OSK induced reprogramming

# %%
start_time <- Sys.time()

# %% [markdown]
# ### Install external packages

# %%
system('apt-get -q install libgsl-dev', intern = TRUE)
# Out:
#  [1] "Reading package lists..."
#  [2] "Building dependency tree..."
#  [3] "Reading state information..."
#  [4] "The following additional packages will be installed:"
#  [5] "  libgsl23 libgslcblas0"
#  [6] "Suggested packages:"
#  [7] "  gsl-ref-psdoc | gsl-doc-pdf | gsl-doc-info | gsl-ref-html"
#  [8] "The following NEW packages will be installed:"
#  [9] "  libgsl-dev libgsl23 libgslcblas0"
# [10] "0 upgraded, 3 newly installed, 0 to remove and 39 not upgraded."
# [11] "Need to get 1,926 kB of archives."
# [12] "After this operation, 9,474 kB of additional disk space will be used."
# [13] "Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgslcblas0 amd64 2.4+dfsg-6 [79.7 kB]"
# [14] "Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgsl23 amd64 2.4+dfsg-6 [823 kB]"
# [15] "Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgsl-dev amd64 2.4+dfsg-6 [1,023 kB]"
# [16] "Fetched 1,926 kB in 1s (1,954 kB/s)"
# [17] "Selecting previously unselected package libgslcblas0:amd64.\r"
# [18] "(Reading database ... \r(Reading database ... 5%\r(Reading database ... 10%\r(Reading database ... 15%\r(Reading database ... 20%\r(Reading database ... 25%\r(Reading database ... 30%\r(Reading database ... 35%\r(Reading database ... 40%\r(Reading database ... 45%\r(Reading database ... 50%\r(Reading database ... 55%\r(Reading database ... 60%\r(Reading database ... 65%\r(Reading database ... 70%\r(Reading database ... 75%\r(Reading database ... 80%\r(Reading database ... 85%\r(Reading database ... 90%\r(Reading database ... 95%\r(Reading database ... 100%\r(Reading database ... 156210 files and directories currently installed.)\r"
# [19] "Preparing to unpack .../libgslcblas0_2.4+dfsg-6_amd64.deb ...\r"
# [20] "Unpacking libgslcblas0:amd64 (2.4+dfsg-6) ...\r"
# [21] "Selecting previously unselected package libgsl23:amd64.\r"
# [22] "Preparing to unpack .../libgsl23_2.4+dfsg-6_amd64.deb ...\r"
# [23] "Unpacking libgsl23:amd64 (2.4+dfsg-6) ...\r"
# [24] "Selecting previously unselected package libgsl-dev.\r"
# [25] "Preparing to unpack .../libgsl-dev_2.4+dfsg-6_amd64.deb ...\r"
# [26] "Unpacking libgsl-dev (2.4+dfsg-6) ...\r"
# [27] "Setting up libgslcblas0:amd64 (2.4+dfsg-6) ...\r"
# [28] "Setting up libgsl23:amd64 (2.4+dfsg-6) ...\r"
# [29] "Setting up libgsl-dev (2.4+dfsg-6) ...\r"
# [30] "Processing triggers for man-db (2.8.3-2ubuntu0.1) ...\r"
# [31] "Processing triggers for libc-bin (2.27-3ubuntu1.3) ...\r"
# [32] "/sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link\r"
# [33] "\r"

# %%
system('apt-get install libcairo2-dev', intern = TRUE) # required by R package ComplexHeatmap
# Out:
#  [1] "Reading package lists..."
#  [2] "Building dependency tree..."
#  [3] "Reading state information..."
#  [4] "The following additional packages will be installed:"
#  [5] "  libcairo-script-interpreter2 libpixman-1-dev libxcb-shm0-dev"
#  [6] "Suggested packages:"
#  [7] "  libcairo2-doc"
#  [8] "The following NEW packages will be installed:"
#  [9] "  libcairo-script-interpreter2 libcairo2-dev libpixman-1-dev libxcb-shm0-dev"
# [10] "0 upgraded, 4 newly installed, 0 to remove and 39 not upgraded."
# [11] "Need to get 930 kB of archives."
# [12] "After this operation, 3,986 kB of additional disk space will be used."
# [13] "Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo-script-interpreter2 amd64 1.15.10-2ubuntu0.1 [53.5 kB]"
# [14] "Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpixman-1-dev amd64 0.34.0-2 [244 kB]"
# [15] "Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-shm0-dev amd64 1.13-2~ubuntu18.04 [6,684 B]"
# [16] "Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo2-dev amd64 1.15.10-2ubuntu0.1 [626 kB]"
# [17] "Fetched 930 kB in 1s (1,198 kB/s)"
# [18] "Selecting previously unselected package libcairo-script-interpreter2:amd64.\r"
# [19] "(Reading database ... \r(Reading database ... 5%\r(Reading database ... 10%\r(Reading database ... 15%\r(Reading database ... 20%\r(Reading database ... 25%\r(Reading database ... 30%\r(Reading database ... 35%\r(Reading database ... 40%\r(Reading database ... 45%\r(Reading database ... 50%\r(Reading database ... 55%\r(Reading database ... 60%\r(Reading database ... 65%\r(Reading database ... 70%\r(Reading database ... 75%\r(Reading database ... 80%\r(Reading database ... 85%\r(Reading database ... 90%\r(Reading database ... 95%\r(Reading database ... 100%\r(Reading database ... 156482 files and directories currently installed.)\r"
# [20] "Preparing to unpack .../libcairo-script-interpreter2_1.15.10-2ubuntu0.1_amd64.deb ...\r"
# [21] "Unpacking libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...\r"
# [22] "Selecting previously unselected package libpixman-1-dev:amd64.\r"
# [23] "Preparing to unpack .../libpixman-1-dev_0.34.0-2_amd64.deb ...\r"
# [24] "Unpacking libpixman-1-dev:amd64 (0.34.0-2) ...\r"
# [25] "Selecting previously unselected package libxcb-shm0-dev:amd64.\r"
# [26] "Preparing to unpack .../libxcb-shm0-dev_1.13-2~ubuntu18.04_amd64.deb ...\r"
# [27] "Unpacking libxcb-shm0-dev:amd64 (1.13-2~ubuntu18.04) ...\r"
# [28] "Selecting previously unselected package libcairo2-dev:amd64.\r"
# [29] "Preparing to unpack .../libcairo2-dev_1.15.10-2ubuntu0.1_amd64.deb ...\r"
# [30] "Unpacking libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...\r"
# [31] "Setting up libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...\r"
# [32] "Setting up libxcb-shm0-dev:amd64 (1.13-2~ubuntu18.04) ...\r"
# [33] "Setting up libpixman-1-dev:amd64 (0.34.0-2) ...\r"
# [34] "Setting up libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...\r"
# [35] "Processing triggers for libc-bin (2.27-3ubuntu1.3) ...\r"
# [36] "/sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link\r"
# [37] "\r"

# %%
system('apt-get install libmagick++-dev', intern = TRUE) # required by magick
system('apt-get install libmagick-dev', intern = TRUE) # for magick
# Out:
#   [1] "Reading package lists..."
#   [2] "Building dependency tree..."
#   [3] "Reading state information..."
#   [4] "The following additional packages will be installed:"
#   [5] "  fonts-droid-fallback fonts-noto-mono ghostscript gir1.2-freedesktop"
#   [6] "  gir1.2-gdkpixbuf-2.0 gir1.2-rsvg-2.0 gsfonts imagemagick-6-common"
#   [7] "  libcupsfilters1 libcupsimage2 libdjvulibre-dev libdjvulibre-text"
#   [8] "  libdjvulibre21 libgdk-pixbuf2.0-dev libgs9 libgs9-common libijs-0.35"
#   [9] "  libjbig2dec0 liblcms2-dev liblqr-1-0 liblqr-1-0-dev libmagick++-6-headers"
#  [10] "  libmagick++-6.q16-7 libmagick++-6.q16-dev libmagickcore-6-arch-config"
#  [11] "  libmagickcore-6-headers libmagickcore-6.q16-3 libmagickcore-6.q16-3-extra"
#  [12] "  libmagickcore-6.q16-dev libmagickwand-6-headers libmagickwand-6.q16-3"
#  [13] "  libmagickwand-6.q16-dev librsvg2-dev libwmf-dev libwmf0.2-7 poppler-data"
#  [14] "Suggested packages:"
#  [15] "  fonts-noto ghostscript-x inkscape libjxr-tools librsvg2-doc libwmf-doc"
#  [16] "  libwmf0.2-7-gtk poppler-utils fonts-japanese-mincho | fonts-ipafont-mincho"
#  [17] "  fonts-japanese-gothic | fonts-ipafont-gothic fonts-arphic-ukai"
#  [18] "  fonts-arphic-uming fonts-nanum"
#  [19] "The following NEW packages will be installed:"
#  [20] "  fonts-droid-fallback fonts-noto-mono ghostscript gir1.2-freedesktop"
#  [21] "  gir1.2-gdkpixbuf-2.0 gir1.2-rsvg-2.0 gsfonts imagemagick-6-common"
#  [22] "  libcupsfilters1 libcupsimage2 libdjvulibre-dev libdjvulibre-text"
#  [23] "  libdjvulibre21 libgdk-pixbuf2.0-dev libgs9 libgs9-common libijs-0.35"
#  [24] "  libjbig2dec0 liblcms2-dev liblqr-1-0 liblqr-1-0-dev libmagick++-6-headers"
#  [25] "  libmagick++-6.q16-7 libmagick++-6.q16-dev libmagick++-dev"
#  [26] "  libmagickcore-6-arch-config libmagickcore-6-headers libmagickcore-6.q16-3"
#  [27] "  libmagickcore-6.q16-3-extra libmagickcore-6.q16-dev libmagickwand-6-headers"
#  [28] "  libmagickwand-6.q16-3 libmagickwand-6.q16-dev librsvg2-dev libwmf-dev"
#  [29] "  libwmf0.2-7 poppler-data"
#  [30] "0 upgraded, 37 newly installed, 0 to remove and 39 not upgraded."
#  [31] "Need to get 30.4 MB of archives."
#  [32] "After this operation, 89.2 MB of additional disk space will be used."
#  [33] "Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-droid-fallback all 1:6.0.1r16-1.1 [1,805 kB]"
#  [34] "Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 imagemagick-6-common all 8:6.9.7.4+dfsg-16ubuntu6.12 [60.3 kB]"
#  [35] "Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagickcore-6-arch-config amd64 8:6.9.7.4+dfsg-16ubuntu6.12 [25.4 kB]"
#  [36] "Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagickcore-6-headers all 8:6.9.7.4+dfsg-16ubuntu6.12 [47.2 kB]"
#  [37] "Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagickwand-6-headers all 8:6.9.7.4+dfsg-16ubuntu6.12 [10.5 kB]"
#  [38] "Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagick++-6-headers all 8:6.9.7.4+dfsg-16ubuntu6.12 [47.2 kB]"
#  [39] "Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 liblqr-1-0 amd64 0.4.2-2.1 [27.7 kB]"
#  [40] "Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagickcore-6.q16-3 amd64 8:6.9.7.4+dfsg-16ubuntu6.12 [1,621 kB]"
#  [41] "Get:9 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagickwand-6.q16-3 amd64 8:6.9.7.4+dfsg-16ubuntu6.12 [292 kB]"
#  [42] "Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagick++-6.q16-7 amd64 8:6.9.7.4+dfsg-16ubuntu6.12 [139 kB]"
#  [43] "Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdjvulibre-text all 3.5.27.1-8ubuntu0.4 [49.4 kB]"
#  [44] "Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdjvulibre21 amd64 3.5.27.1-8ubuntu0.4 [561 kB]"
#  [45] "Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwmf0.2-7 amd64 0.2.8.4-12 [150 kB]"
#  [46] "Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagickcore-6.q16-3-extra amd64 8:6.9.7.4+dfsg-16ubuntu6.12 [62.4 kB]"
#  [47] "Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdjvulibre-dev amd64 3.5.27.1-8ubuntu0.4 [2,382 kB]"
#  [48] "Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 liblcms2-dev amd64 2.9-1ubuntu0.1 [9,096 kB]"
#  [49] "Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 liblqr-1-0-dev amd64 0.4.2-2.1 [69.1 kB]"
#  [50] "Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-freedesktop amd64 1.56.1-1 [9,080 B]"
#  [51] "Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-gdkpixbuf-2.0 amd64 2.36.11-2 [7,748 B]"
#  [52] "Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gir1.2-rsvg-2.0 amd64 2.40.20-2ubuntu0.2 [3,764 B]"
#  [53] "Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdk-pixbuf2.0-dev amd64 2.36.11-2 [46.8 kB]"
#  [54] "Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 librsvg2-dev amd64 2.40.20-2ubuntu0.2 [10.7 kB]"
#  [55] "Get:23 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwmf-dev amd64 0.2.8.4-12 [172 kB]"
#  [56] "Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagickcore-6.q16-dev amd64 8:6.9.7.4+dfsg-16ubuntu6.12 [974 kB]"
#  [57] "Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagickwand-6.q16-dev amd64 8:6.9.7.4+dfsg-16ubuntu6.12 [290 kB]"
#  [58] "Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagick++-6.q16-dev amd64 8:6.9.7.4+dfsg-16ubuntu6.12 [119 kB]"
#  [59] "Get:27 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagick++-dev all 8:6.9.7.4+dfsg-16ubuntu6.12 [1,408 B]"
#  [60] "Get:28 http://archive.ubuntu.com/ubuntu bionic/main amd64 poppler-data all 0.4.8-2 [1,479 kB]"
#  [61] "Get:29 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-noto-mono all 20171026-2 [75.5 kB]"
#  [62] "Get:30 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcupsimage2 amd64 2.2.7-1ubuntu2.8 [18.6 kB]"
#  [63] "Get:31 http://archive.ubuntu.com/ubuntu bionic/main amd64 libijs-0.35 amd64 0.35-13 [15.5 kB]"
#  [64] "Get:32 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjbig2dec0 amd64 0.13-6 [55.9 kB]"
#  [65] "Get:33 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgs9-common all 9.26~dfsg+0-0ubuntu0.18.04.15 [5,092 kB]"
#  [66] "Get:34 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgs9 amd64 9.26~dfsg+0-0ubuntu0.18.04.15 [2,265 kB]"
#  [67] "Get:35 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 ghostscript amd64 9.26~dfsg+0-0ubuntu0.18.04.15 [51.4 kB]"
#  [68] "Get:36 http://archive.ubuntu.com/ubuntu bionic/main amd64 gsfonts all 1:8.11+urwcyr1.0.7~pre44-4.4 [3,120 kB]"
#  [69] "Get:37 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcupsfilters1 amd64 1.20.2-0ubuntu3.1 [108 kB]"
#  [70] "Fetched 30.4 MB in 2s (16.7 MB/s)"
#  [71] "Selecting previously unselected package fonts-droid-fallback.\r"
#  [72] "(Reading database ... \r(Reading database ... 5%\r(Reading database ... 10%\r(Reading database ... 15%\r(Reading database ... 20%\r(Reading database ... 25%\r(Reading database ... 30%\r(Reading database ... 35%\r(Reading database ... 40%\r(Reading database ... 45%\r(Reading database ... 50%\r(Reading database ... 55%\r(Reading database ... 60%\r(Reading database ... 65%\r(Reading database ... 70%\r(Reading database ... 75%\r(Reading database ... 80%\r(Reading database ... 85%\r(Reading database ... 90%\r(Reading database ... 95%\r(Reading database ... 100%\r(Reading database ... 156542 files and directories currently installed.)\r"
#  [73] "Preparing to unpack .../00-fonts-droid-fallback_1%3a6.0.1r16-1.1_all.deb ...\r"
#  [74] "Unpacking fonts-droid-fallback (1:6.0.1r16-1.1) ...\r"
# ...
# [40] "Selecting previously unselected package libgraphics-magick-perl.\r"
# [41] "Preparing to unpack .../1-libgraphics-magick-perl_1.3.28-2ubuntu0.1_amd64.deb ...\r"
# [42] "Unpacking libgraphics-magick-perl (1.3.28-2ubuntu0.1) ...\r"
# [43] "Selecting previously unselected package libgraphicsmagick++-q16-12.\r"
# [44] "Preparing to unpack .../2-libgraphicsmagick++-q16-12_1.3.28-2ubuntu0.1_amd64.deb ...\r"
# [45] "Unpacking libgraphicsmagick++-q16-12 (1.3.28-2ubuntu0.1) ...\r"
# [46] "Selecting previously unselected package libgraphicsmagick1-dev.\r"
# [47] "Preparing to unpack .../3-libgraphicsmagick1-dev_1.3.28-2ubuntu0.1_amd64.deb ...\r"
# [48] "Unpacking libgraphicsmagick1-dev (1.3.28-2ubuntu0.1) ...\r"
# [49] "Selecting previously unselected package libgraphicsmagick++1-dev.\r"
# [50] "Preparing to unpack .../4-libgraphicsmagick++1-dev_1.3.28-2ubuntu0.1_amd64.deb ...\r"
# [51] "Unpacking libgraphicsmagick++1-dev (1.3.28-2ubuntu0.1) ...\r"
# [52] "Selecting previously unselected package graphicsmagick-libmagick-dev-compat.\r"
# [53] "Preparing to unpack .../5-graphicsmagick-libmagick-dev-compat_1.3.28-2ubuntu0.1_all.deb ...\r"
# [54] "Unpacking graphicsmagick-libmagick-dev-compat (1.3.28-2ubuntu0.1) ...\r"
# [55] "Setting up libgraphicsmagick-q16-3 (1.3.28-2ubuntu0.1) ...\r"
# [56] "Setting up libgraphics-magick-perl (1.3.28-2ubuntu0.1) ...\r"
# [57] "Setting up libgraphicsmagick++-q16-12 (1.3.28-2ubuntu0.1) ...\r"
# [58] "Setting up libgraphicsmagick1-dev (1.3.28-2ubuntu0.1) ...\r"
# [59] "Setting up libgraphicsmagick++1-dev (1.3.28-2ubuntu0.1) ...\r"
# [60] "Setting up graphicsmagick-libmagick-dev-compat (1.3.28-2ubuntu0.1) ...\r"
# [61] "Processing triggers for man-db (2.8.3-2ubuntu0.1) ...\r"
# [62] "Processing triggers for libc-bin (2.27-3ubuntu1.3) ...\r"
# [63] "/sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link\r"
# [64] "\r"

# %% [markdown]
# ### Install R packages

# %%
install.packages('BiocManager')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
required_packages <- c(
  'devtools', 
  'dplyr',
  'BSgenome.Mmusculus.UCSC.mm10', 'TxDb.Mmusculus.UCSC.mm10.knownGene', 'org.Mm.eg.db',
  'magick', 'patchwork', 'ggrepel',
  'chromVAR', 'motifmatchr',
  'EnrichedHeatmap', 'circlize', 
  'ChIPseeker', 'clusterProfiler'
)

# %%
missing_packages <- required_packages[!required_packages %in% rownames(installed.packages())]
if (length(missing_packages) > 0){
    BiocManager::install(missing_packages)
}
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# '?repositories' for details
#
# replacement repositories:
#     CRAN: https://cran.rstudio.com
#
#
# Bioconductor version 3.14 (BiocManager 1.30.16), R 4.1.3 (2022-03-10)
#
# Installing package(s) 'BiocVersion', 'BSgenome.Mmusculus.UCSC.mm10',
#   'TxDb.Mmusculus.UCSC.mm10.knownGene', 'org.Mm.eg.db', 'magick', 'patchwork',
#   'ggrepel', 'chromVAR', 'motifmatchr', 'EnrichedHeatmap', 'circlize',
#   'ChIPseeker', 'clusterProfiler'
#
# also installing the dependencies ‘filelock’, ‘formatR’, ‘pracma’, ‘R.oo’, ‘R.methodsS3’, ‘gridGraphics’, ‘tweenr’, ‘polyclip’, ‘plogr’, ‘BiocFileCache’, ‘lambda.r’, ‘futile.options’, ‘poweRlaw’, ‘annotate’, ‘R.utils’, ‘iterators’, ‘ggfun’, ‘ggplotify’, ‘ggforce’, ‘viridis’, ‘tidygraph’, ‘graphlayouts’, ‘ape’, ‘tidytree’, ‘treeio’, ‘gridExtra’, ‘fastmatch’, ‘XVector’, ‘RSQLite’, ‘RCurl’, ‘BiocIO’, ‘biomaRt’, ‘Biobase’, ‘KEGGREST’, ‘GenomeInfoDbData’, ‘RcppEigen’, ‘BH’, ‘futile.logger’, ‘snow’, ‘caTools’, ‘CNEr’, ‘DirichletMultinomial’, ‘seqLogo’, ‘TFMPvalue’, ‘XML’, ‘zlibbioc’, ‘bitops’, ‘Rhtslib’, ‘htmlwidgets’, ‘lazyeval’, ‘crosstalk’, ‘promises’, ‘httpuv’, ‘xtable’, ‘fontawesome’, ‘sourcetools’, ‘later’, ‘MatrixGenerics’, ‘DelayedArray’, ‘clue’, ‘png’, ‘foreach’, ‘doParallel’, ‘rjson’, ‘aplot’, ‘ggraph’, ‘igraph’, ‘reshape2’, ‘scatterpie’, ‘shadowtext’, ‘ggtree’, ‘GenomicAlignments’, ‘restfulr’, ‘DO.db’, ‘fgsea’, ‘BSgenome’, ‘GenomicFeatures’, ‘AnnotationDbi’, ‘IRanges’, ‘GenomeInfoDb’, ‘GenomicRanges’, ‘nabor’, ‘BiocParallel’, ‘BiocGenerics’, ‘Biostrings’, ‘TFBSTools’, ‘Rsamtools’, ‘S4Vectors’, ‘plotly’, ‘shiny’, ‘miniUI’, ‘DT’, ‘Rtsne’, ‘SummarizedExperiment’, ‘RcppArmadillo’, ‘ComplexHeatmap’, ‘matrixStats’, ‘GetoptLong’, ‘locfit’, ‘GlobalOptions’, ‘shape’, ‘enrichplot’, ‘gplots’, ‘gtools’, ‘plotrix’, ‘rtracklayer’, ‘TxDb.Hsapiens.UCSC.hg19.knownGene’, ‘downloader’, ‘DOSE’, ‘GO.db’, ‘GOSemSim’, ‘plyr’, ‘qvalue’, ‘yulab.utils’
#
#
# Old packages: 'crayon', 'fansi', 'gert', 'knitr', 'magrittr', 'processx',
#   'RColorBrewer', 'readxl', 'rprojroot', 'sass', 'testthat', 'tinytex', 'tzdb',
#   'vctrs', 'cluster', 'MASS', 'Matrix', 'mgcv', 'nlme'

# %%
library(devtools)
# Out:
# Loading required package: usethis

# %% [markdown]
# ### Install SeATAC from github

# %%
install_github('gongx030/seatac@v0.4.0', force = TRUE, quiet = FALSE)
reload(pkgload::inst("seatac"))
library(seatac)
# Out:
# Downloading GitHub repo gongx030/seatac@v0.4.0
# RColorBrewer (1.1-2 -> 1.1-3 ) [CRAN]
# crayon       (1.5.0 -> 1.5.1 ) [CRAN]
# vctrs        (0.3.8 -> 0.4.0 ) [CRAN]
# fansi        (1.0.2 -> 1.0.3 ) [CRAN]
# magrittr     (2.0.2 -> 2.0.3 ) [CRAN]
# rprojroot    (2.0.2 -> 2.0.3 ) [CRAN]
# tfautograph  (NA    -> 0.3.2 ) [CRAN]
# processx     (3.5.2 -> 3.5.3 ) [CRAN]
# config       (NA    -> 0.3.1 ) [CRAN]
# here         (NA    -> 1.0.1 ) [CRAN]
# RcppTOML     (NA    -> 0.1.7 ) [CRAN]
# zeallot      (NA    -> 0.1.0 ) [CRAN]
# tfruns       (NA    -> 1.5.0 ) [CRAN]
# tensorflow   (NA    -> 2.8.0 ) [CRAN]
# reticulate   (NA    -> 1.24  ) [CRAN]
# keras        (NA    -> 2.8.0 ) [CRAN]
# abind        (NA    -> 1.4-5 ) [CRAN]
# tfdatasets   (NA    -> 2.7.0 ) [CRAN]
# tfprobabi... (NA    -> 0.15.0) [CRAN]
# Installing 19 packages: RColorBrewer, crayon, vctrs, fansi, magrittr, rprojroot, tfautograph, processx, config, here, RcppTOML, zeallot, tfruns, tensorflow, reticulate, keras, abind, tfdatasets, tfprobability
#
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# * checking for file ‘/tmp/RtmpGurOW2/remotes6122af21b0/gongx030-seatac-55f9f36/DESCRIPTION’ ... OK
# * preparing ‘seatac’:
# * checking DESCRIPTION meta-information ... OK
# * checking for LF line-endings in source and make files and shell scripts
# * checking for empty or unneeded directories
# Omitted ‘LazyData’ from DESCRIPTION
# * building ‘seatac_0.4.0-010.tar.gz’
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: tensorflow
#
# Loading required package: tfprobability
#
# Loading required package: tfdatasets
#
# Loading required package: GenomicRanges
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘Biobase’
#
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
#
#
# Attaching package: ‘seatac’
#
#
# The following object is masked from ‘package:tfdatasets’:
#
#     fit
#
#
# The following object is masked from ‘package:stats’:
#
#     predict

# %% [markdown]
# ### Install other non-CRAN packages

# %%
devtools::install_github("GreenleafLab/chromVARmotifs")
# Out:
# Downloading GitHub repo GreenleafLab/chromVARmotifs@HEAD
# tzdb (0.2.0 -> 0.3.0) [CRAN]
# Installing 1 packages: tzdb
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# * checking for file ‘/tmp/RtmpGurOW2/remotes6124e371c6/GreenleafLab-chromVARmotifs-38bed55/DESCRIPTION’ ... OK
# * preparing ‘chromVARmotifs’:
# * checking DESCRIPTION meta-information ... OK
# * checking for LF line-endings in source and make files and shell scripts
# * checking for empty or unneeded directories
# * building ‘chromVARmotifs_0.2.0.tar.gz’
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %% [markdown]
# ### Load R packages

# %%
library(GenomicRanges)
library(motifmatchr)
library(chromVARmotifs)
library(patchwork)
library(dplyr)
library(seatac)
library(GenomicRanges)
library(BSgenome.Mmusculus.UCSC.mm10)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
#
# The following object is masked from ‘package:matrixStats’:
#
#     count
#
#
# The following objects are masked from ‘package:GenomicRanges’:
#
#     intersect, setdiff, union
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: BSgenome
#
# Loading required package: Biostrings
#
# Loading required package: XVector
#
#
# Attaching package: ‘Biostrings’
#
#
# The following object is masked from ‘package:base’:
#
#     strsplit
#
#
# Loading required package: rtracklayer

# %%
library(GenomicRanges)
library(BSgenome.Mmusculus.UCSC.mm10)
library(dplyr)
library(ggplot2)
library(magick)
library(patchwork)
library(chromVAR)
library(motifmatchr)
library(chromVARmotifs)
library(ggrepel)
library(circlize)
library(EnrichedHeatmap)
library(TxDb.Mmusculus.UCSC.mm10.knownGene)
library(org.Mm.eg.db)
library(ChIPseeker)
library(clusterProfiler)
library(RColorBrewer)
# Out:
# Linking to ImageMagick 6.9.7.4
# Enabled features: fontconfig, freetype, fftw, lcms, pango, x11
# Disabled features: cairo, ghostscript, heic, raw, rsvg, webp
#
# Using 8 threads
#
# ========================================
# circlize version 0.4.14
# CRAN page: https://cran.r-project.org/package=circlize
# Github page: https://github.com/jokergoo/circlize
# Documentation: https://jokergoo.github.io/circlize_book/book/
#
# If you use it in published research, please cite:
# Gu, Z. circlize implements and enhances circular visualization
#   in R. Bioinformatics 2014.
#
# This message can be suppressed by:
#   suppressPackageStartupMessages(library(circlize))
# ========================================
#
#
# Loading required package: grid
#
#
# Attaching package: ‘grid’
#
#
# The following object is masked from ‘package:Biostrings’:
#
#     pattern
#
#
# Loading required package: ComplexHeatmap
#
# ========================================
# ComplexHeatmap version 2.10.0
# Bioconductor page: http://bioconductor.org/packages/ComplexHeatmap/
# Github page: https://github.com/jokergoo/ComplexHeatmap
# Documentation: http://jokergoo.github.io/ComplexHeatmap-reference
#
# If you use it in published research, please cite:
# Gu, Z. Complex heatmaps reveal patterns and correlations in multidimensional
#   genomic data. Bioinformatics 2016.
#
# The new InteractiveComplexHeatmap package can directly export static
# complex heatmaps into an interactive Shiny app with zero effort. Have a try!
#
# This message can be suppressed by:
#   suppressPackageStartupMessages(library(ComplexHeatmap))
# ========================================
#
#
# ========================================
# EnrichedHeatmap version 1.24.0
# Bioconductor page: http://bioconductor.org/packages/EnrichedHeatmap/
# Github page: https://github.com/jokergoo/EnrichedHeatmap
# Documentation: http://bioconductor.org/packages/EnrichedHeatmap/
#
# If you use it in published research, please cite:
# Gu, Z. EnrichedHeatmap: an R/Bioconductor package for comprehensive
# visualization of genomic signal associations. BMC Genomics 2018.
#
# This message can be suppressed by:
#   suppressPackageStartupMessages(library(EnrichedHeatmap))
# ========================================
#
#
# Loading required package: GenomicFeatures
#
# Loading required package: AnnotationDbi
#
#
# Attaching package: ‘AnnotationDbi’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     select
#
#
#
#
# Registered S3 method overwritten by 'ggtree':
#   method      from
#   identify.gg ggfun
#
# ChIPseeker v1.30.3  For help: https://guangchuangyu.github.io/software/ChIPseeker
#
# If you use ChIPseeker in published research, please cite:
# Guangchuang Yu, Li-Gen Wang, Qing-Yu He. ChIPseeker: an R/Bioconductor package for ChIP peak annotation, comparison and visualization. Bioinformatics 2015, 31(14):2382-2383
#
# clusterProfiler v4.2.2  For help: https://yulab-smu.top/biomedical-knowledge-mining-book/
#
# If you use clusterProfiler in published research, please cite:
# T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu. clusterProfiler 4.0: A universal enrichment tool for interpreting omics data. The Innovation. 2021, 2(3):100141
#
#
# Attaching package: ‘clusterProfiler’
#
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
#
# The following object is masked from ‘package:XVector’:
#
#     slice
#
#
# The following object is masked from ‘package:IRanges’:
#
#     slice
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     rename
#
#
# The following object is masked from ‘package:stats’:
#
#     filter

# %% [markdown]
# ### TensorFlow setup

# %%
gpus <- tf$config$list_physical_devices('GPU')
for (gpu in gpus){
  tf$config$experimental$set_memory_growth(gpu, TRUE)
}
logical_gpus <- tf$config$experimental$list_logical_devices('GPU')
sprintf('Physical GPUs: %d', length(gpus)) %>% message()
sprintf('Logical GPUs: %d', length(logical_gpus)) %>% message()
# Out:
# Loaded Tensorflow version 2.8.0
#
# Physical GPUs: 1
#
# Logical GPUs: 1

# %%
Sys.time() - start_time
# Out:
# Time difference of 37.80809 mins

# %% [markdown]
# ## Parameters

# %%
ARGS <- list(
  bin_size = 5L,
  fragment_size_range_max = 640L,
  fragment_size_interval = 10L,
  window_size = 1000L,
  heatmap_window_size = 2000L,
  block_size = 640L,
  sliding_step = 20L,
  min_reads = 5L,
  step_size = 200L,

  vae_num_peaks = 5000L,
  vae_latent = c(10L),
  vae_filters0 = c(128L),
  vae_filters = c(32L),
  vae_downsample_layers = 4L,
  vae_upsample_layers = 4L,
  vae_base_learning_rate = c(1e-2),
  vae_epochs = 200L,
  vae_beta_schedule_method = c('constant'),
  vae_beta0 = 1,
  vae_batch_size = c(128L),
  vae_warmup_ratio = 0.1,

  target_width = 100L,
  min_test_reads = 1L,
  max_test_reads = 10L,
  center_width = 100L # the center width
)

# %% [markdown]
# ## Load BAM files

# %%
remote_bam_files <- c(
  MEF = 'https://s3.msi.umn.edu/dsouz072/datasets/dataset=iPSC_reprogramming_version=20200208a/MEF.dedup.bam',
  MEF_OSK_D7 = 'https://s3.msi.umn.edu/dsouz072/datasets/dataset=iPSC_reprogramming_version=20200208a/OSK_D7.dedup.bam'
)
for (i in 1:length(remote_bam_files)){
  sprintf('wget -cx %s', remote_bam_files[i]) %>% system()
}

# %%
local_bam_files <- gsub('https://', './', remote_bam_files)
all(file.exists(local_bam_files))
# Out:
# [1] TRUE

# %% [markdown]
# ## Load bed files

# %%
remote_bed_files <- gsub('.bam', '_summits.bed', remote_bam_files)
for (i in 1:length(remote_bed_files)){
  sprintf('wget -cx %s', remote_bed_files[i]) %>% system()
}
local_bed_files <- gsub('https://', './', remote_bed_files)
all(file.exists(local_bed_files))
# Out:
# [1] TRUE

# %% [markdown]
# ## Training VAE

# %%
models <- list()

# %%
cond <- c('MEF', 'MEF_OSK_D7')

# %%
gr0 <- lapply(local_bed_files[cond], function(bed_file){
  peaks <- read.table(bed_file, header = FALSE, sep = '\t')
  peaks <- GRanges(seqnames = peaks[, 1], range = IRanges(start = peaks[, 2], end = peaks[, 3]))
  peaks <- resize(peaks, fix = 'center', width = ARGS[['step_size']])
  peaks
}) %>%
  GRangesList() %>%
  coverage() %>%
  IRanges::slice(lower = 1, rangesOnly = TRUE) %>%
  GRanges() %>%
  resize(fix = 'center', width = ARGS[['window_size']])
gr0 <- gr0[!seqnames(gr0) %in% c('chrM', 'chrY')]

# %%
gr <- slidingWindows(gr0, width = ARGS[['block_size']], step = ARGS[['sliding_step']]) %>% unlist()
set.seed(1L); gr <- sample(gr, ARGS[['vae_num_peaks']])
counts <- count_reads(gr, local_bam_files[cond], genome = BSgenome.Mmusculus.UCSC.mm10,  fragment_size_range = c(0, ARGS[['fragment_size_range_max']]))
# Out:
# validate_bam | indexing bam files: ./s3.msi.umn.edu/dsouz072/datasets/dataset=iPSC_reprogramming_version=20200208a/MEF.dedup.bam
#
# read_bam | reading ./s3.msi.umn.edu/dsouz072/datasets/dataset=iPSC_reprogramming_version=20200208a/MEF.dedup.bam
#
# validate_bam | indexing bam files: ./s3.msi.umn.edu/dsouz072/datasets/dataset=iPSC_reprogramming_version=20200208a/OSK_D7.dedup.bam
#
# read_bam | reading ./s3.msi.umn.edu/dsouz072/datasets/dataset=iPSC_reprogramming_version=20200208a/OSK_D7.dedup.bam

# %%
valid <- rowSums(counts >= ARGS[['min_reads']]) == length(cond)
gr <- gr[valid]
sprintf('number of training peaks for VaeModel: %d', length(gr)) %>% message()
# Out:
# number of training peaks for VaeModel: 4358

# %%
x <- read_vplot(
  gr, 
  filenames = local_bam_files[cond], 
  genome = BSgenome.Mmusculus.UCSC.mm10, 
  bin_size = ARGS[['bin_size']], 
  fragment_size_range = c(0, ARGS[['fragment_size_range_max']]), 
  fragment_size_interval = ARGS[['fragment_size_interval']]
)
# Out:
# read_bam | reading ./s3.msi.umn.edu/dsouz072/datasets/dataset=iPSC_reprogramming_version=20200208a/MEF.dedup.bam
#
# read_bam | reading ./s3.msi.umn.edu/dsouz072/datasets/dataset=iPSC_reprogramming_version=20200208a/OSK_D7.dedup.bam

# %%
model <- new('VaeModel', model = VaeModel(
  n_samples = dim(x)['sample'],
  latent_dim = ARGS[['vae_latent']],
  block_size = ARGS[['block_size']],
  bin_size = ARGS[['bin_size']],
  filters0 = ARGS[['vae_filters0']],
  filters = ARGS[['vae_filters']],
  upsample_layers = ARGS[['vae_upsample_layers']],
  downsample_layers = ARGS[['vae_downsample_layers']],
  fragment_size_range  = c(0, ARGS[['fragment_size_range_max']]),
  fragment_size_interval = ARGS[['fragment_size_interval']]
))
lr <- WarmUpAndCosineDecay(
  base_learning_rate = ARGS[['vae_base_learning_rate']],
  num_examples = nrow(x),
  batch_size = ARGS[['vae_batch_size']],
  epochs = ARGS[['vae_epochs']],
  warmup_epochs = as.integer(ARGS[['vae_epochs']] * ARGS[['vae_warmup_ratio']])
)
beta <- beta_schedule(
  method = ARGS[['vae_beta_schedule_method']],
  beta0 = ARGS[['vae_beta0']],
  epochs = ARGS[['vae_epochs']]
)
d <- model %>% prepare_data(x)
d <- d %>% tensor_slices_dataset()
models[['MEF']] <- model %>% fit(d, batch_size =  ARGS[['vae_batch_size']], epochs = ARGS[['vae_epochs']], learning_rate = lr, compile = TRUE, beta = beta)
# Out:
# epoch=     1/   200 | beta=1.000e+00 | loss= 7160.4536412 | loss_reconstruction= 7159.3571289 | loss_kl=    1.0964913
#
# epoch=     2/   200 | beta=1.000e+00 | loss= 5544.1317801 | loss_reconstruction= 5537.3243862 | loss_kl=    6.8073740
#
# epoch=     3/   200 | beta=1.000e+00 | loss= 4767.5948521 | loss_reconstruction= 4759.0843471 | loss_kl=    8.5104885
#
# epoch=     4/   200 | beta=1.000e+00 | loss= 3905.1298828 | loss_reconstruction= 3899.9843262 | loss_kl=    5.1455589
#
# epoch=     5/   200 | beta=1.000e+00 | loss= 2823.8772252 | loss_reconstruction= 2821.1746233 | loss_kl=    2.7025882
#
# epoch=     6/   200 | beta=1.000e+00 | loss= 1758.8801025 | loss_reconstruction= 1757.7006801 | loss_kl=    1.1794179
#
# epoch=     7/   200 | beta=1.000e+00 | loss= 1017.3664621 | loss_reconstruction= 1016.8739171 | loss_kl=    0.4925427
#
# epoch=     8/   200 | beta=1.000e+00 | loss=  629.7411900 | loss_reconstruction=  629.5313668 | loss_kl=    0.2098244
#
# epoch=     9/   200 | beta=1.000e+00 | loss=  449.0731210 | loss_reconstruction=  448.9580296 | loss_kl=    0.1150920
#
# epoch=    10/   200 | beta=1.000e+00 | loss=  362.4754421 | loss_reconstruction=  362.3219892 | loss_kl=    0.1534522
#
# epoch=    11/   200 | beta=1.000e+00 | loss=  316.7016706 | loss_reconstruction=  316.1537040 | loss_kl=    0.5479661
#
# epoch=    12/   200 | beta=1.000e+00 | loss=  289.0930620 | loss_reconstruction=  287.9601759 | loss_kl=    1.1328881
#
# epoch=    13/   200 | beta=1.000e+00 | loss=  270.5398930 | loss_reconstruction=  268.5589037 | loss_kl=    1.9809875
#
# epoch=    14/   200 | beta=1.000e+00 | loss=  258.2688607 | loss_reconstruction=  255.6855988 | loss_kl=    2.5832597
#
# epoch=    15/   200 | beta=1.000e+00 | loss=  249.1890167 | loss_reconstruction=  246.0319946 | loss_kl=    3.1570215
#
# epoch=    16/   200 | beta=1.000e+00 | loss=  242.1088479 | loss_reconstruction=  238.7825296 | loss_kl=    3.3263193
#
# epoch=    17/   200 | beta=1.000e+00 | loss=  237.1848005 | loss_reconstruction=  233.5339634 | loss_kl=    3.6508369
#
# epoch=    18/   200 | beta=1.000e+00 | loss=  234.2677691 | loss_reconstruction=  230.3497720 | loss_kl=    3.9179979
#
# epoch=    19/   200 | beta=1.000e+00 | loss=  231.6673174 | loss_reconstruction=  227.5420088 | loss_kl=    4.1253089
#
#
# epoch=    44/   200 | beta=1.000e+00 | loss=  223.1451015 | loss_reconstruction=  216.8976955 | loss_kl=    6.2474049
#
# epoch=    45/   200 | beta=1.000e+00 | loss=  222.6365457 | loss_reconstruction=  216.4269457 | loss_kl=    6.2095993
#
# epoch=    46/   200 | beta=1.000e+00 | loss=  222.3037027 | loss_reconstruction=  216.1316166 | loss_kl=    6.1720850
#
# epoch=    47/   200 | beta=1.000e+00 | loss=  222.2976118 | loss_reconstruction=  215.9758955 | loss_kl=    6.3217156
#
# epoch=    48/   200 | beta=1.000e+00 | loss=  222.2868264 | loss_reconstruction=  215.9521515 | loss_kl=    6.3346742
#
# epoch=    49/   200 | beta=1.000e+00 | loss=  222.3742410 | loss_reconstruction=  216.0046330 | loss_kl=    6.3696074
#
# epoch=    50/   200 | beta=1.000e+00 | loss=  222.1269431 | loss_reconstruction=  215.7262421 | loss_kl=    6.4007016
#
# epoch=    51/   200 | beta=1.000e+00 | loss=  221.9566515 | loss_reconstruction=  215.5597713 | loss_kl=    6.3968806
#
# epoch=    52/   200 | beta=1.000e+00 | loss=  221.9200152 | loss_reconstruction=  215.5686275 | loss_kl=    6.3513876
#
# epoch=    53/   200 | beta=1.000e+00 | loss=  221.7204429 | loss_reconstruction=  215.2286473 | loss_kl=    6.4917947
#
# epoch=    54/   200 | beta=1.000e+00 | loss=  221.7829686 | loss_reconstruction=  215.2827475 | loss_kl=    6.5002220
#
# epoch=    55/   200 | beta=1.000e+00 | loss=  221.9051958 | loss_reconstruction=  215.5094046 | loss_kl=    6.3957911
#
# epoch=    56/   200 | beta=1.000e+00 | loss=  221.4232596 | loss_reconstruction=  214.7856820 | loss_kl=    6.6375790
#
# epoch=    57/   200 | beta=1.000e+00 | loss=  221.2058158 | loss_reconstruction=  214.5222996 | loss_kl=    6.6835161
#
# epoch=    58/   200 | beta=1.000e+00 | loss=  222.8292873 | loss_reconstruction=  216.4274118 | loss_kl=    6.4018756
#
# epoch=    59/   200 | beta=1.000e+00 | loss=  222.1582903 | loss_reconstruction=  215.3577890 | loss_kl=    6.8005012
#
# epoch=    60/   200 | beta=1.000e+00 | loss=  220.9133793 | loss_reconstruction=  214.3212585 | loss_kl=    6.5921208
#
# epoch=    61/   200 | beta=1.000e+00 | loss=  220.2581975 | loss_reconstruction=  213.6231066 | loss_kl=    6.6350901
#
# epoch=    62/   200 | beta=1.000e+00 | loss=  220.6406812 | loss_reconstruction=  213.9639143 | loss_kl=    6.6767653
#
# epoch=    63/   200 | beta=1.000e+00 | loss=  221.5498352 | loss_reconstruction=  214.7051195 | loss_kl=    6.8447159
#
# epoch=    64/   200 | beta=1.000e+00 | loss=  220.1611659 | loss_reconstruction=  213.4663679 | loss_kl=    6.6947977
#
# epoch=    65/   200 | beta=1.000e+00 | loss=  219.8578308 | loss_reconstruction=  213.1735613 | loss_kl=    6.6842691
#
# epoch=    66/   200 | beta=1.000e+00 | loss=  219.8864027 | loss_reconstruction=  213.1091167 | loss_kl=    6.7772862
#
# epoch=    67/   200 | beta=1.000e+00 | loss=  219.9870139 | loss_reconstruction=  213.1191480 | loss_kl=    6.8678662
#
# epoch=    68/   200 | beta=1.000e+00 | loss=  221.0657235 | loss_reconstruction=  214.1961779 | loss_kl=    6.8695453
#
# epoch=    69/   200 | beta=1.000e+00 | loss=  224.0900652 | loss_reconstruction=  217.4528486 | loss_kl=    6.6372172
#
# epoch=    70/   200 | beta=1.000e+00 | loss=  220.2380380 | loss_reconstruction=  213.4605865 | loss_kl=    6.7774496
#
# epoch=    71/   200 | beta=1.000e+00 | loss=  219.4077506 | loss_reconstruction=  212.4841973 | loss_kl=    6.9235528
#
# epoch=    72/   200 | beta=1.000e+00 | loss=  220.9738582 | loss_reconstruction=  214.0748086 | loss_kl=    6.8990494
#
# epoch=    73/   200 | beta=1.000e+00 | loss=  219.7070103 | loss_reconstruction=  212.8010509 | loss_kl=    6.9059607
#
# epoch=    74/   200 | beta=1.000e+00 | loss=  219.4666081 | loss_reconstruction=  212.6672433 | loss_kl=    6.7993640
#
# epoch=    75/   200 | beta=1.000e+00 | loss=  240.9820840 | loss_reconstruction=  235.1172019 | loss_kl=    5.8648843
#
# epoch=    76/   200 | beta=1.000e+00 | loss=  233.8830200 | loss_reconstruction=  227.8059588 | loss_kl=    6.0770628
#
# epoch=    77/   200 | beta=1.000e+00 | loss=  227.4102116 | loss_reconstruction=  221.2062413 | loss_kl=    6.2039701
#
# epoch=    78/   200 | beta=1.000e+00 | loss=  225.3333601 | loss_reconstruction=  219.1617017 | loss_kl=    6.1716581
#
# epoch=    79/   200 | beta=1.000e+00 | loss=  224.4215820 | loss_reconstruction=  218.2449506 | loss_kl=    6.1766316
#
# epoch=    80/   200 | beta=1.000e+00 | loss=  223.9847482 | loss_reconstruction=  217.8278360 | loss_kl=    6.1569131
#
# epoch=    81/   200 | beta=1.000e+00 | loss=  223.4121259 | loss_reconstruction=  217.1250759 | loss_kl=    6.2870502
#
# epoch=    82/   200 | beta=1.000e+00 | loss=  223.3477866 | loss_reconstruction=  217.0835624 | loss_kl=    6.2642242
#
# epoch=    83/   200 | beta=1.000e+00 | loss=  223.0180908 | loss_reconstruction=  216.7034847 | loss_kl=    6.3146069
#
# epoch=    84/   200 | beta=1.000e+00 | loss=  222.5356703 | loss_reconstruction=  216.1744716 | loss_kl=    6.3611980
#
# epoch=    85/   200 | beta=1.000e+00 | loss=  222.3499363 | loss_reconstruction=  216.0542720 | loss_kl=    6.2956645
#
# epoch=    86/   200 | beta=1.000e+00 | loss=  222.2178336 | loss_reconstruction=  215.8025718 | loss_kl=    6.4152609
#
# epoch=    87/   200 | beta=1.000e+00 | loss=  222.1597913 | loss_reconstruction=  215.7062757 | loss_kl=    6.4535164
#
# epoch=    88/   200 | beta=1.000e+00 | loss=  221.8586400 | loss_reconstruction=  215.3875571 | loss_kl=    6.4710838
#
# epoch=    89/   200 | beta=1.000e+00 | loss=  221.9184998 | loss_reconstruction=  215.3716016 | loss_kl=    6.5468993
# epoch=   182/   200 | beta=1.000e+00 | loss=  214.0344391 | loss_reconstruction=  206.6803479 | loss_kl=    7.3540901
#
# epoch=   183/   200 | beta=1.000e+00 | loss=  214.0336330 | loss_reconstruction=  206.6610995 | loss_kl=    7.3725348
#
# epoch=   184/   200 | beta=1.000e+00 | loss=  214.0778878 | loss_reconstruction=  206.7488140 | loss_kl=    7.3290731
#
# epoch=   185/   200 | beta=1.000e+00 | loss=  214.0587139 | loss_reconstruction=  206.6857697 | loss_kl=    7.3729425
#
# epoch=   186/   200 | beta=1.000e+00 | loss=  214.0147305 | loss_reconstruction=  206.6778021 | loss_kl=    7.3369282
#
# epoch=   187/   200 | beta=1.000e+00 | loss=  213.9996217 | loss_reconstruction=  206.6895244 | loss_kl=    7.3100983
#
# epoch=   188/   200 | beta=1.000e+00 | loss=  214.0459369 | loss_reconstruction=  206.6673818 | loss_kl=    7.3785548
#
# epoch=   189/   200 | beta=1.000e+00 | loss=  214.0583135 | loss_reconstruction=  206.6776326 | loss_kl=    7.3806815
#
# epoch=   190/   200 | beta=1.000e+00 | loss=  214.0324311 | loss_reconstruction=  206.5927108 | loss_kl=    7.4397204
#
# epoch=   191/   200 | beta=1.000e+00 | loss=  214.0084457 | loss_reconstruction=  206.5806841 | loss_kl=    7.4277607
#
# epoch=   192/   200 | beta=1.000e+00 | loss=  214.0098818 | loss_reconstruction=  206.6751306 | loss_kl=    7.3347514
#
# epoch=   193/   200 | beta=1.000e+00 | loss=  213.9981384 | loss_reconstruction=  206.6178447 | loss_kl=    7.3802951
#
# epoch=   194/   200 | beta=1.000e+00 | loss=  214.0303915 | loss_reconstruction=  206.6939771 | loss_kl=    7.3364148
#
# epoch=   195/   200 | beta=1.000e+00 | loss=  213.9987840 | loss_reconstruction=  206.6056972 | loss_kl=    7.3930867
#
# epoch=   196/   200 | beta=1.000e+00 | loss=  213.9855200 | loss_reconstruction=  206.5374193 | loss_kl=    7.4481006
#
# epoch=   197/   200 | beta=1.000e+00 | loss=  213.9917951 | loss_reconstruction=  206.5590249 | loss_kl=    7.4327697
#
# epoch=   198/   200 | beta=1.000e+00 | loss=  214.0406036 | loss_reconstruction=  206.5809906 | loss_kl=    7.4596140
#
# epoch=   199/   200 | beta=1.000e+00 | loss=  214.0274634 | loss_reconstruction=  206.5988973 | loss_kl=    7.4285676
#
# epoch=   200/   200 | beta=1.000e+00 | loss=  213.9836855 | loss_reconstruction=  206.5666819 | loss_kl=    7.4170042

# %% [markdown]
# ## Download related `pileup` and `fold enrichment` bigwig files

# %%
remote_bw_files <- c(
	'MNase'                             = 'https://s3.msi.umn.edu/gongx030/datasets/dataset=Chronis_version=20170519a/MNase_treat_pileup.bw',
	'H3'                                = 'https://s3.msi.umn.edu/gongx030/datasets/dataset=Chronis_version=20170519a/H3_treat_pileup.bw',
	'H3K9me3'                           = 'https://s3.msi.umn.edu/gongx030/datasets/dataset=Chronis_version=20170519a/H3K9me3_treat_pileup.bw',
	'H3K27me3'                          = 'https://s3.msi.umn.edu/gongx030/datasets/dataset=Chronis_version=20170519a/H3K27me3_treat_pileup.bw',
	'H3K36me3'                          = 'https://s3.msi.umn.edu/gongx030/datasets/dataset=Chronis_version=20170519a/H3K36me3_treat_pileup.bw',
	'H3K9ac'                            = 'https://s3.msi.umn.edu/gongx030/datasets/dataset=Chronis_version=20170519a/H3K9ac_treat_pileup.bw',
	'H3K79me2'                          = 'https://s3.msi.umn.edu/gongx030/datasets/dataset=Chronis_version=20170519a/H3K79me2_treat_pileup.bw',
	'H3K4me2'                           = 'https://s3.msi.umn.edu/gongx030/datasets/dataset=Chronis_version=20170519a/H3K4me2_treat_pileup.bw',
	'H3K4me1'                           = 'https://s3.msi.umn.edu/gongx030/datasets/dataset=Chronis_version=20170519a/H3K4me1_treat_pileup.bw',
	'Hdac1'                             = 'https://s3.msi.umn.edu/gongx030/datasets/dataset=Chronis_version=20170519a/Hdac1_treat_pileup.bw',
	'H3.3'                              = 'https://s3.msi.umn.edu/gongx030/datasets/dataset=Chronis_version=20170519a/H3.3_treat_pileup.bw',
	'P300'                              = 'https://s3.msi.umn.edu/gongx030/datasets/dataset=Chronis_version=20170519a/P300_treat_pileup.bw'
	
)

# %%
for (i in 1:length(remote_bw_files)){
  sprintf('wget -cx %s', remote_bw_files[i]) %>% system()
}

# %%
local_bw_files <- gsub('https://', './', remote_bw_files)

# %% [markdown]
# ## OSK motif

# %%
osk_regions <- read.table('https://s3.msi.umn.edu/dsouz072/datasets/dataset=iPSC_reprogramming_version=20200208a/OSK_Motif_binding_sites.bed', sep = '\t')

# %%
gr <- GRanges(seqnames = osk_regions[, 1], range = IRanges(start = osk_regions[, 2], end = osk_regions[, 3]), score = osk_regions[, 4])

# %%
sprintf('number of OSK motif-centric regions: %s', length(gr)) %>% message()
# Out:
# number of OSK motif-centric regions: 282789

# %% [markdown]
# ### Read motif centric V-plots

# %%
x_MEF <- read_vplot(gr, filenames = local_bam_files[c('MEF', 'MEF_OSK_D7')], genome = BSgenome.Mmusculus.UCSC.mm10, bin_size = ARGS[['bin_size']], fragment_size_range = c(0, ARGS[['fragment_size_range_max']]), fragment_size_interval = ARGS[['fragment_size_interval']])
# Out:
# read_bam | reading ./s3.msi.umn.edu/dsouz072/datasets/dataset=iPSC_reprogramming_version=20200208a/MEF.dedup.bam
#
# read_bam | reading ./s3.msi.umn.edu/dsouz072/datasets/dataset=iPSC_reprogramming_version=20200208a/OSK_D7.dedup.bam

# %% [markdown]
# ### Get the latent representations of the V-plots

# %%
x_MEF <- models[['MEF']] %>% predict(x_MEF, batch_size = ARGS[['vae_batch_size']], vplots = FALSE)

# %% [markdown]
# ### Calling significant V-plots

# %%
res_MEF <- models[['MEF']] %>% results(x_MEF, type = 'vplots', contrast = c('name', 'MEF', 'MEF_OSK_D7'), width = ARGS[['center_width']])
res_MEF$group <- 'MEF'
res <- c(res_MEF)
res$NOR_NFR <- res$padj < 0.05 & res$log_ratio < -0.1
res$NFR_NOR <- res$padj < 0.05 & res$log_ratio > 0.1

# %%
res_new <- res[res$padj < 0.05 ]

# %% [markdown]
# ### Read significant regions V-plots

# %%
seqlevels(res_new) <- seqlevels(gr)

# %%
x_MEF <- read_vplot(res_new, filenames = local_bam_files[c('MEF', 'MEF_OSK_D7')], genome = BSgenome.Mmusculus.UCSC.mm10, bin_size = ARGS[['bin_size']], fragment_size_range = c(0, ARGS[['fragment_size_range_max']]), fragment_size_interval = ARGS[['fragment_size_interval']])
# Out:
# read_bam | reading ./s3.msi.umn.edu/dsouz072/datasets/dataset=iPSC_reprogramming_version=20200208a/MEF.dedup.bam
#
# read_bam | reading ./s3.msi.umn.edu/dsouz072/datasets/dataset=iPSC_reprogramming_version=20200208a/OSK_D7.dedup.bam

# %% [markdown]
# ### Get estimated counts for regions with Vplots differentially significant

# %%
x_MEF <- models[['MEF']] %>% predict(x_MEF, batch_size = ARGS[['vae_batch_size']], vplots = TRUE)

# %%
res_w <- resize(res_new, width = 2000L, fix = 'center')

# %%
options(repr.plot.width = 9, repr.plot.height = 9)
i <- res_new$padj < 0.05 & res_new$log_ratio > 0.1
table(i)
p1 <- vplot(x_MEF[i], 'predicted_counts')
i <- res_new$padj < 0.05 & res_new$log_ratio < -0.1
table(i)
p2 <- vplot(x_MEF[i], 'predicted_counts')
p1 / p2
# Out:
# i
# FALSE  TRUE
# 19368  4415
# i
# FALSE  TRUE
#  8063 15720
# Warning message:
# “Removed 128 rows containing missing values (geom_raster).”
# Warning message:
# “Removed 128 rows containing missing values (geom_raster).”
# plot without title

# %% [markdown]
# ### Prepare `noramlizedMatrix` for `EnrichedHeatmap`

# %%
cvg <- list()
for (i in 1:length(local_bw_files)){
  cvg[[names(local_bw_files)[i]]] <- rtracklayer::import(local_bw_files[i], which = res_w)
}

# %%
smooth <- FALSE
extend <- ARGS[['heatmap_window_size']] / 2 - ARGS[['target_width']] / 2
target_ratio <- 1 / (2 * extend  / ARGS[['target_width']] + 1)
sprintf('target_ratio:%.3f', target_ratio) %>% message()
# Out:
# target_ratio:0.050

# %%
is_MEF <- grepl('^MEF_', names(local_bw_files)) | names(local_bw_files) %in% c('MNase', 'H3', 'H3K9me3', 'H3K27me3', 'H3K36me3', 'H3K9ac', 'H3K79me2', 'H3K4me2', 'H3K4me1', 'Hdac1', 'H3.3', 'P300')

# %%
mat <- list()

# %%
mat[['MEF']] <- lapply(cvg[is_MEF], function(cvgi){
  normalizeToMatrix(
    cvgi,
    resize(res_w[res_w$group == 'MEF' & (res_w$NOR_NFR | res_w$NFR_NOR)], fix = 'center', width = ARGS[['target_width']]),
    extend = extend, 
    value_column = 'score', 
    mean_mode = 'w0', 
    w = 10, 
    smooth = smooth, 
    target_ratio = target_ratio
  )
})

# %%
group_cols <- c(
	'MNase'                             = 'black',
	'H3'                                = 'black',
	'H3K9me3'                           = 'orange',
	'H3K27me3'                          = 'orange',
	'H3K36me3'                          = 'orange',
	'H3K9ac'                            = 'orange',
	'H3K79me2'                          = 'orange',
	'H3K4me2'                           = 'orange',
	'H3K4me1'                           = 'orange',
	'Hdac1'                             = 'black',
	'H3.3'                              = 'black',
	'P300'                              = 'blue'
)

# %% [markdown]
# ### MEF heatmaps

# %%
col_fun <- lapply(names(mat[['MEF']]), function(i) colorRamp2(quantile(mat[['MEF']][[i]], c(0.005, 0.995)), c('white', group_cols[i])))
names(col_fun) <- names(mat[['MEF']])

# %%
sp <- res_w[res_w$group == 'MEF' & (res_w$NOR_NFR | res_w$NFR_NOR)]$NOR_NFR
sp <- factor(sp, c(TRUE, FALSE), labels = c('NOR_NFR', 'NFR_NOR'))
table(sp)
# Out:
# sp
# NOR_NFR NFR_NOR
#   15720    4415

# %%
lgd <- Legend(
  at = c('NOR_NFR', 'NFR_NOR'),
  title = "Clusters", 
  type = "lines", 
  legend_gp = gpar(col = 1:2)
)
ta <- HeatmapAnnotation(
  enriched = anno_enriched(
    gp = gpar(col = 1:2, lty = 1, lwd = 2),
    axis_param = list(facing = 'inside',at = -1000)
  )
)
ht_list <- Heatmap(
  as.character(sp), 
  col = structure(1:2, names = c('NOR_NFR', 'NFR_NOR')),
  name = "partition",
  show_row_names = FALSE, 
  width = unit(3, "mm")
) + 
 EnrichedHeatmap(
  mat[['MEF']][['MNase']],
  col = col_fun[['MNase']],
  top_annotation = ta,
  pos_line = TRUE,
  name = 'MNase'
) + EnrichedHeatmap(
  mat[['MEF']][['H3K27me3']],
  col = col_fun[['H3K27me3']],
  top_annotation = ta,
  pos_line = TRUE,
  name = 'H3K27me3'
) + EnrichedHeatmap(
  mat[['MEF']][['H3K36me3']],
  col = col_fun[['H3K36me3']],
  top_annotation = ta,
  pos_line = TRUE,
  name = 'H3K36me3'
) + EnrichedHeatmap(
  mat[['MEF']][['H3K9ac']],
  col = col_fun[['H3K9ac']],
  top_annotation = ta,
  pos_line = TRUE,
  name = 'H3K9ac'
) + EnrichedHeatmap(
  mat[['MEF']][['H3K79me2']],
  col = col_fun[['H3K79me2']],
  top_annotation = ta,
  pos_line = TRUE,
  name = 'H3K79me2'
) + EnrichedHeatmap(
  mat[['MEF']][['H3K4me2']],
  col = col_fun[['H3K4me2']],
  top_annotation = ta,
  pos_line = TRUE,
  name = 'H3K4me2'
) + EnrichedHeatmap(
  mat[['MEF']][['H3K4me1']],
  col = col_fun[['H3K4me1']],
  top_annotation = ta,
  pos_line = TRUE,
  name = 'H3K4me1'
) + EnrichedHeatmap(
  mat[['MEF']][['P300']],
  col = col_fun[['P300']],
  top_annotation = ta,
  pos_line = TRUE,
  name = 'P300'
)
# Out:
# `use_raster` is automatically set to TRUE for a matrix with more than
# 2000 rows. You can control `use_raster` argument by explicitly setting
# TRUE/FALSE to it.
#
# Set `ht_opt$message = FALSE` to turn off this message.
#
# `use_raster` is automatically set to TRUE for a matrix with more than
# 2000 rows. You can control `use_raster` argument by explicitly setting
# TRUE/FALSE to it.
#
# Set `ht_opt$message = FALSE` to turn off this message.
#
# `use_raster` is automatically set to TRUE for a matrix with more than
# 2000 rows. You can control `use_raster` argument by explicitly setting
# TRUE/FALSE to it.
#
# Set `ht_opt$message = FALSE` to turn off this message.
#
# `use_raster` is automatically set to TRUE for a matrix with more than
# 2000 rows. You can control `use_raster` argument by explicitly setting
# TRUE/FALSE to it.
#
# Set `ht_opt$message = FALSE` to turn off this message.
#
# `use_raster` is automatically set to TRUE for a matrix with more than
# 2000 rows. You can control `use_raster` argument by explicitly setting
# TRUE/FALSE to it.
#
# Set `ht_opt$message = FALSE` to turn off this message.
#
# `use_raster` is automatically set to TRUE for a matrix with more than
# 2000 rows. You can control `use_raster` argument by explicitly setting
# TRUE/FALSE to it.
#
# Set `ht_opt$message = FALSE` to turn off this message.
#
# `use_raster` is automatically set to TRUE for a matrix with more than
# 2000 rows. You can control `use_raster` argument by explicitly setting
# TRUE/FALSE to it.
#
# Set `ht_opt$message = FALSE` to turn off this message.
#
# `use_raster` is automatically set to TRUE for a matrix with more than
# 2000 rows. You can control `use_raster` argument by explicitly setting
# TRUE/FALSE to it.
#
# Set `ht_opt$message = FALSE` to turn off this message.

# %%
options(repr.plot.width = 20, repr.plot.height = 12)
draw(ht_list, split = sp, annotation_legend_list = list(lgd), heatmap_legend_side = "bottom")
# Out:
# plot without title

# %% [markdown]
# ## Prepare data for pathway analysis

# %%
grl <- list(
  MEF_NOR_NFR = granges(res_new[res_new$group == 'MEF' & res_new$NOR_NFR]),
  MEF_NFR_NOR = granges(res_new[res_new$group == 'MEF' & res_new$NFR_NOR])
)

# %%
pl <- lapply(grl, function(s) annotatePeak(s, tssRegion = c(-2000, 500),TxDb = TxDb.Mmusculus.UCSC.mm10.knownGene,annoDb = 'org.Mm.eg.db'))
# Out:
# >> preparing features information...		 2022-04-01 02:44:57 PM
# >> identifying nearest features...		 2022-04-01 02:44:58 PM
# >> calculating distance from peak to TSS...	 2022-04-01 02:44:58 PM
# >> assigning genomic annotation...		 2022-04-01 02:44:58 PM
# >> adding gene annotation...			 2022-04-01 02:45:14 PM
# 'select()' returned 1:many mapping between keys and columns
# >> assigning chromosome lengths			 2022-04-01 02:45:14 PM
# >> done...					 2022-04-01 02:45:14 PM
# >> preparing features information...		 2022-04-01 02:45:14 PM
# >> identifying nearest features...		 2022-04-01 02:45:14 PM
# >> calculating distance from peak to TSS...	 2022-04-01 02:45:14 PM
# >> assigning genomic annotation...		 2022-04-01 02:45:14 PM
# >> adding gene annotation...			 2022-04-01 02:45:16 PM
# 'select()' returned 1:many mapping between keys and columns
# >> assigning chromosome lengths			 2022-04-01 02:45:17 PM
# >> done...					 2022-04-01 02:45:17 PM

# %% [markdown]
# ## Examine the genomic distribution of NOR->NFR and NFR->NOR groups

# %%
options(repr.plot.width = 8, repr.plot.height = 7)
plotAnnoBar(pl)
# Out:
# plot without title

# %%
sp <- lapply(pl, function(xx) unique(as.data.frame(xx)$geneId))
lapply(sp,length)
# Out:
# $MEF_NOR_NFR
# [1] 8103
#
# $MEF_NFR_NOR
# [1] 3479

# %% [markdown]
# ## SessionInfo

# %%
sessionInfo()
# Out:
# R version 4.1.3 (2022-03-10)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 18.04.5 LTS
#
# Matrix products: default
# BLAS:   /usr/lib/x86_64-linux-gnu/openblas/libblas.so.3
# LAPACK: /usr/lib/x86_64-linux-gnu/libopenblasp-r0.2.20.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] grid      stats4    stats     graphics  grDevices utils     datasets
# [8] methods   base
#
# other attached packages:
#  [1] RColorBrewer_1.1-2
#  [2] clusterProfiler_4.2.2
#  [3] ChIPseeker_1.30.3
#  [4] org.Mm.eg.db_3.14.0
#  [5] TxDb.Mmusculus.UCSC.mm10.knownGene_3.10.0
#  [6] GenomicFeatures_1.46.5
#  [7] AnnotationDbi_1.56.2
#  [8] EnrichedHeatmap_1.24.0
#  [9] ComplexHeatmap_2.10.0
# [10] circlize_0.4.14
# [11] ggrepel_0.9.1
# [12] chromVAR_1.16.0
# [13] magick_2.7.3
# [14] ggplot2_3.3.5
# [15] BSgenome.Mmusculus.UCSC.mm10_1.4.3
# [16] BSgenome_1.62.0
# [17] rtracklayer_1.54.0
# [18] Biostrings_2.62.0
# [19] XVector_0.34.0
# [20] dplyr_1.0.8
# [21] patchwork_1.1.1
# [22] chromVARmotifs_0.2.0
# [23] motifmatchr_1.16.0
# [24] seatac_0.4.0-010
# [25] SummarizedExperiment_1.24.0
# [26] Biobase_2.54.0
# [27] MatrixGenerics_1.6.0
# [28] matrixStats_0.61.0
# [29] GenomicRanges_1.46.1
# [30] GenomeInfoDb_1.30.1
# [31] IRanges_2.28.0
# [32] S4Vectors_0.32.4
# [33] BiocGenerics_0.40.0
# [34] tfdatasets_2.7.0
# [35] tfprobability_0.15.0
# [36] tensorflow_2.8.0
# [37] devtools_2.4.3
# [38] usethis_2.1.5
#
# loaded via a namespace (and not attached):
#   [1] rappdirs_0.3.3
#   [2] pbdZMQ_0.3-7
#   [3] R.methodsS3_1.8.1
#   [4] tidyr_1.2.0
#   [5] bit64_4.0.5
#   [6] DelayedArray_0.20.0
#   [7] R.utils_2.11.0
#   [8] data.table_1.14.2
#   [9] KEGGREST_1.34.0
#  [10] TFBSTools_1.32.0
#  [11] RCurl_1.98-1.6
#  [12] doParallel_1.0.17
#  [13] generics_0.1.2
#  [14] callr_3.7.0
#  [15] RSQLite_2.2.11
#  [16] shadowtext_0.1.1
#  [17] bit_4.0.4
#  [18] tzdb_0.3.0
#  [19] enrichplot_1.14.2
#  [20] xml2_1.3.3
#  [21] httpuv_1.6.5
#  [22] assertthat_0.2.1
#  [23] DirichletMultinomial_1.36.0
#  [24] viridis_0.6.2
#  [25] hms_1.1.1
#  [26] evaluate_0.15
#  [27] promises_1.2.0.1
#  [28] fansi_1.0.2
#  [29] restfulr_0.0.13
#  [30] progress_1.2.2
#  [31] caTools_1.18.2
#  [32] dbplyr_2.1.1
#  [33] igraph_1.3.0
#  [34] DBI_1.1.2
#  [35] htmlwidgets_1.5.4
#  [36] purrr_0.3.4
#  [37] ellipsis_0.3.2
#  [38] backports_1.4.1
#  [39] annotate_1.72.0
#  [40] biomaRt_2.50.3
#  [41] vctrs_0.3.8
#  [42] here_1.0.1
#  [43] remotes_2.4.2
#  [44] abind_1.4-5
#  [45] cachem_1.0.6
#  [46] withr_2.5.0
#  [47] ggforce_0.3.3
#  [48] GenomicAlignments_1.30.0
#  [49] treeio_1.18.1
#  [50] prettyunits_1.1.1
#  [51] cluster_2.1.2
#  [52] DOSE_3.20.1
#  [53] ape_5.6-2
#  [54] IRdisplay_1.1
#  [55] lazyeval_0.2.2
#  [56] seqLogo_1.60.0
#  [57] crayon_1.5.0
#  [58] labeling_0.4.2
#  [59] pkgconfig_2.0.3
#  [60] tweenr_1.0.2
#  [61] nlme_3.1-155
#  [62] pkgload_1.2.4
#  [63] rlang_1.0.2
#  [64] lifecycle_1.0.1
#  [65] miniUI_0.1.1.1
#  [66] downloader_0.4
#  [67] filelock_1.0.2
#  [68] BiocFileCache_2.2.1
#  [69] rprojroot_2.0.2
#  [70] polyclip_1.10-0
#  [71] Matrix_1.4-0
#  [72] aplot_0.1.3
#  [73] IRkernel_1.3
#  [74] boot_1.3-28
#  [75] base64enc_0.1-3
#  [76] whisker_0.4
#  [77] GlobalOptions_0.1.2
#  [78] processx_3.5.2
#  [79] png_0.1-7
#  [80] viridisLite_0.4.0
#  [81] rjson_0.2.21
#  [82] bitops_1.0-7
#  [83] R.oo_1.24.0
#  [84] KernSmooth_2.23-20
#  [85] blob_1.2.2
#  [86] shape_1.4.6
#  [87] stringr_1.4.0
#  [88] qvalue_2.26.0
#  [89] readr_2.1.2
#  [90] gridGraphics_0.5-1
#  [91] CNEr_1.30.0
#  [92] scales_1.1.1
#  [93] memoise_2.0.1
#  [94] magrittr_2.0.2
#  [95] plyr_1.8.7
#  [96] gplots_3.1.1
#  [97] zlibbioc_1.40.0
#  [98] compiler_4.1.3
#  [99] scatterpie_0.1.7
# [100] BiocIO_1.4.0
# [101] plotrix_3.8-2
# [102] clue_0.3-60
# [103] Rsamtools_2.10.0
# [104] cli_3.2.0
# [105] ps_1.6.0
# [106] MASS_7.3-55
# [107] tidyselect_1.1.2
# [108] stringi_1.7.6
# [109] yaml_2.3.5
# [110] GOSemSim_2.20.0
# [111] locfit_1.5-9.5
# [112] fastmatch_1.1-3
# [113] tools_4.1.3
# [114] parallel_4.1.3
# [115] uuid_1.0-4
# [116] TFMPvalue_0.0.8
# [117] foreach_1.5.2
# [118] TxDb.Hsapiens.UCSC.hg19.knownGene_3.2.2
# [119] gridExtra_2.3
# [120] farver_2.1.0
# [121] ggraph_2.0.5
# [122] digest_0.6.29
# [123] BiocManager_1.30.16
# [124] shiny_1.7.1
# [125] pracma_2.3.8
# [126] Rcpp_1.0.8.3
# [127] tfautograph_0.3.2
# [128] later_1.3.0
# [129] httr_1.4.2
# [130] colorspace_2.0-3
# [131] brio_1.1.3
# [132] XML_3.99-0.9
# [133] fs_1.5.2
# [134] reticulate_1.24
# [135] splines_4.1.3
# [136] yulab.utils_0.0.4
# [137] tidytree_0.3.9
# [138] graphlayouts_0.8.0
# [139] ggplotify_0.1.0
# [140] plotly_4.10.0
# [141] sessioninfo_1.2.2
# [142] xtable_1.8-4
# [143] jsonlite_1.8.0
# [144] ggtree_3.2.1
# [145] poweRlaw_0.70.6
# [146] tidygraph_1.2.0
# [147] zeallot_0.1.0
# [148] keras_2.8.0
# [149] ggfun_0.0.6
# [150] testthat_3.1.2
# [151] R6_2.5.1
# [152] pillar_1.7.0
# [153] htmltools_0.5.2
# [154] mime_0.12
# [155] glue_1.6.2
# [156] fastmap_1.1.0
# [157] DT_0.22
# [158] BiocParallel_1.28.3
# [159] codetools_0.2-18
# [160] fgsea_1.20.0
# [161] pkgbuild_1.3.1
# [162] utf8_1.2.2
# [163] lattice_0.20-45
# [164] tibble_3.1.6
# [165] curl_4.3.2
# [166] tfruns_1.5.0
# [167] gtools_3.9.2
# [168] GO.db_3.14.0
# [169] repr_1.1.4
# [170] desc_1.4.1
# [171] munsell_0.5.0
# [172] DO.db_2.9
# [173] GetoptLong_1.0.5
# [174] GenomeInfoDbData_1.2.7
# [175] iterators_1.0.14
# [176] reshape2_1.4.4
# [177] gtable_0.3.0

# %%
Sys.time() - start_time
# Out:
# Time difference of 1.871283 hours
