# %% [markdown]
# <a href="https://colab.research.google.com/github/gongx030/seatac_manuscript/blob/main/Ascl1_MEF_motifs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Comparing chromVAR and SeATAC on detecting differential motifs in Ascl1 induced neruon reprogramming

# %%
start_time <- Sys.time()

# %% [markdown]
# ### Install external packages

# %%
system('apt-get -q install libgsl-dev', intern = TRUE)
# Out:
#  [1] "Reading package lists..."
#  [2] "Building dependency tree..."
#  [3] "Reading state information..."
#  [4] "The following additional packages will be installed:"
#  [5] "  libgsl23 libgslcblas0"
#  [6] "Suggested packages:"
#  [7] "  gsl-ref-psdoc | gsl-doc-pdf | gsl-doc-info | gsl-ref-html"
#  [8] "The following NEW packages will be installed:"
#  [9] "  libgsl-dev libgsl23 libgslcblas0"
# [10] "0 upgraded, 3 newly installed, 0 to remove and 39 not upgraded."
# [11] "Need to get 1,926 kB of archives."
# [12] "After this operation, 9,474 kB of additional disk space will be used."
# [13] "Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgslcblas0 amd64 2.4+dfsg-6 [79.7 kB]"
# [14] "Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgsl23 amd64 2.4+dfsg-6 [823 kB]"
# [15] "Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgsl-dev amd64 2.4+dfsg-6 [1,023 kB]"
# [16] "Fetched 1,926 kB in 3s (736 kB/s)"
# ...

# %%
system('apt-get install libcairo2-dev', intern = TRUE) # required by R package ComplexHeatmap
# Out:
#  [1] "Reading package lists..."
#  [2] "Building dependency tree..."
#  [3] "Reading state information..."
#  [4] "The following additional packages will be installed:"
#  [5] "  libcairo-script-interpreter2 libpixman-1-dev libxcb-shm0-dev"
#  [6] "Suggested packages:"
#  [7] "  libcairo2-doc"
#  [8] "The following NEW packages will be installed:"
#  [9] "  libcairo-script-interpreter2 libcairo2-dev libpixman-1-dev libxcb-shm0-dev"
# [10] "0 upgraded, 4 newly installed, 0 to remove and 39 not upgraded."
# [11] "Need to get 930 kB of archives."
# [12] "After this operation, 3,986 kB of additional disk space will be used."
# [13] "Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo-script-interpreter2 amd64 1.15.10-2ubuntu0.1 [53.5 kB]"
# [14] "Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpixman-1-dev amd64 0.34.0-2 [244 kB]"
# [15] "Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-shm0-dev amd64 1.13-2~ubuntu18.04 [6,684 B]"
# ...

# %%
system('apt-get install libmagick++-dev', intern = TRUE) # required by magick
# Out:
#   [1] "Reading package lists..."
#   [2] "Building dependency tree..."
#   [3] "Reading state information..."
#   [4] "The following additional packages will be installed:"
#   [5] "  fonts-droid-fallback fonts-noto-mono ghostscript gir1.2-freedesktop"
#   [6] "  gir1.2-gdkpixbuf-2.0 gir1.2-rsvg-2.0 gsfonts imagemagick-6-common"
#   [7] "  libcupsfilters1 libcupsimage2 libdjvulibre-dev libdjvulibre-text"
#   [8] "  libdjvulibre21 libgdk-pixbuf2.0-dev libgs9 libgs9-common libijs-0.35"
#   [9] "  libjbig2dec0 liblcms2-dev liblqr-1-0 liblqr-1-0-dev libmagick++-6-headers"
#  [10] "  libmagick++-6.q16-7 libmagick++-6.q16-dev libmagickcore-6-arch-config"
#  [11] "  libmagickcore-6-headers libmagickcore-6.q16-3 libmagickcore-6.q16-3-extra"
#  [12] "  libmagickcore-6.q16-dev libmagickwand-6-headers libmagickwand-6.q16-3"
#  [13] "  libmagickwand-6.q16-dev librsvg2-dev libwmf-dev libwmf0.2-7 poppler-data"
#  [14] "Suggested packages:"
# ...

# %% [markdown]
# ### Install R packages

# %%
install.packages('BiocManager')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
required_packages <- c(
  'devtools', 
  'dplyr',
  'BSgenome.Mmusculus.UCSC.mm10',
  'magick', 'patchwork',
  'chromVAR', 'motifmatchr'
)

# %%
missing_packages <- required_packages[!required_packages %in% rownames(installed.packages())]
if (length(missing_packages) > 0){
    BiocManager::install(missing_packages)
}
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# '?repositories' for details
#
# replacement repositories:
#     CRAN: https://cran.rstudio.com
#
#
# Bioconductor version 3.14 (BiocManager 1.30.16), R 4.1.3 (2022-03-10)
#
# Installing package(s) 'BiocVersion', 'BSgenome.Mmusculus.UCSC.mm10', 'magick',
#   'patchwork', 'chromVAR', 'motifmatchr'
#
# ...

# %%
library(devtools)
# Out:
# Loading required package: usethis

# %% [markdown]
# ### Install SeATAC from github

# %%
install_github('gongx030/seatac@v0.4.0', force = TRUE, quiet = FALSE)
reload(pkgload::inst("seatac"))
library(seatac)
# Out:
# ...
# crayon       (1.5.0 -> 1.5.1 ) [CRAN]
# fansi        (1.0.2 -> 1.0.3 ) [CRAN]
# tfautograph  (NA    -> 0.3.2 ) [CRAN]
# processx     (3.5.2 -> 3.5.3 ) [CRAN]
# config       (NA    -> 0.3.1 ) [CRAN]
# here         (NA    -> 1.0.1 ) [CRAN]
# RcppTOML     (NA    -> 0.1.7 ) [CRAN]
# zeallot      (NA    -> 0.1.0 ) [CRAN]
# tfruns       (NA    -> 1.5.0 ) [CRAN]
# tensorflow   (NA    -> 2.8.0 ) [CRAN]
# reticulate   (NA    -> 1.24  ) [CRAN]
# keras        (NA    -> 2.8.0 ) [CRAN]
# abind        (NA    -> 1.4-5 ) [CRAN]
# gplots       (NA    -> 3.1.1 ) [CRAN]
# tfdatasets   (NA    -> 2.7.0 ) [CRAN]
# tfprobabi... (NA    -> 0.15.0) [CRAN]
# Installing 16 packages: crayon, fansi, tfautograph, processx, config, here, RcppTOML, zeallot, tfruns, tensorflow, reticulate, keras, abind, gplots, tfdatasets, tfprobability
#
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# ...

# %% [markdown]
# ### Install other non-CRAN packages

# %%
devtools::install_github("GreenleafLab/chromVARmotifs")
# Out:
# ...
# tzdb (0.2.0 -> 0.3.0) [CRAN]
# Installing 1 packages: tzdb
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# * checking for file ‘/tmp/RtmphLf4BA/remotes543fe02ca7/GreenleafLab-chromVARmotifs-38bed55/DESCRIPTION’ ... OK
# * preparing ‘chromVARmotifs’:
# * checking DESCRIPTION meta-information ... OK
# * checking for LF line-endings in source and make files and shell scripts
# * checking for empty or unneeded directories
# * building ‘chromVARmotifs_0.2.0.tar.gz’
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %% [markdown]
# ### Load R packages

# %%
BiocManager::install('ggrepel')
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# '?repositories' for details
#
# replacement repositories:
#     CRAN: https://cran.rstudio.com
#
#
# Bioconductor version 3.14 (BiocManager 1.30.16), R 4.1.3 (2022-03-10)
#
# Installing package(s) 'ggrepel'
#
# Old packages: 'crayon', 'fansi', 'gert', 'knitr', 'processx', 'readxl', 'sass',
#   'testthat', 'tinytex', 'tzdb', 'cluster', 'MASS', 'Matrix', 'mgcv', 'nlme'

# %%
library(GenomicRanges)
library(BSgenome.Mmusculus.UCSC.mm10)
library(dplyr)
library(ggplot2)
library(magick)
library(patchwork)
library(chromVAR)
library(motifmatchr)
library(chromVARmotifs)
library(ggrepel)

# %%
Sys.time() - start_time
# Out:
# Time difference of 30.74183 mins

# %% [markdown]
# ## Parameters

# %%
ARGS <- list(
  fragment_size_range_max = 640L,
  fragment_size_interval = 10L,
  window_size = 1000L,
  block_size = 640L,
  sliding_step = 20L,
  min_reads = 5L,
  step_size = 200L,
  log_ratio_cutoff = 0.2
)

# %% [markdown]
# ## Load BAM files

# %%
remote_bam_files <- c(
  MEF = 'https://s3.msi.umn.edu/dsouz072/datasets/dataset=Ascl1_version=20200128a/MEF.bam',
  MEF_Ascl1_D22 = 'https://s3.msi.umn.edu/dsouz072/datasets/dataset=Ascl1_version=20200128a/MEF_Ascl1_22d.bam'
)
for (i in 1:length(remote_bam_files)){
  sprintf('wget -cx %s', remote_bam_files[i]) %>% system()
}

# %%
local_bam_files <- gsub('https://', './', remote_bam_files)
all(file.exists(local_bam_files))
# Out:
# [1] TRUE

# %% [markdown]
# ## Load bed files

# %%
remote_bed_files <- gsub('.bam', '_summits.bed', remote_bam_files)
for (i in 1:length(remote_bed_files)){
  sprintf('wget -cx %s', remote_bed_files[i]) %>% system()
}
local_bed_files <- gsub('https://', './', remote_bed_files)
all(file.exists(local_bed_files))
# Out:
# [1] TRUE

# %% [markdown]
# ## chromVAR analysis on MEF data

# %%
gr0 <- lapply(local_bed_files, function(bed_file){
  peaks <- read.table(bed_file, header = FALSE, sep = '\t')
  peaks <- GRanges(seqnames = peaks[, 1], range = IRanges(start = peaks[, 2], end = peaks[, 3]))
  peaks <- resize(peaks, fix = 'center', width = ARGS[['step_size']])
  peaks
}) %>%
  GRangesList() %>%
  coverage() %>%
  IRanges::slice(lower = 1, rangesOnly = TRUE) %>%
  GRanges() %>%
  resize(fix = 'center', width = ARGS[['window_size']])
gr0 <- gr0[!seqnames(gr0) %in% c('chrM', 'chrY')]

# %%
counts <- count_reads(
  resize(gr0, width = ARGS[['block_size']], fix = 'center'),
  local_bam_files, 
  genome = BSgenome.Mmusculus.UCSC.mm10,  
  fragment_size_range = c(0, 10000)
)
# Out:
# validate_bam | indexing bam files: ./s3.msi.umn.edu/dsouz072/datasets/dataset=Ascl1_version=20200128a/MEF.bam
#
# read_bam | reading ./s3.msi.umn.edu/dsouz072/datasets/dataset=Ascl1_version=20200128a/MEF.bam
#
# validate_bam | indexing bam files: ./s3.msi.umn.edu/dsouz072/datasets/dataset=Ascl1_version=20200128a/MEF_Ascl1_22d.bam
#
# read_bam | reading ./s3.msi.umn.edu/dsouz072/datasets/dataset=Ascl1_version=20200128a/MEF_Ascl1_22d.bam

# %%
se_MEF <- SummarizedExperiment(
  assays = list(counts = counts),
  rowRanges = gr0,
  colData = data.frame(group = c('MEF', 'MEF_Ascl1_D22'))
)
se_MEF <- addGCBias(se_MEF, genome = BSgenome.Mmusculus.UCSC.mm10)
se_MEF <- se_MEF[rowSums(assays(se_MEF)$counts > 0) >= 2]

# %%
motif_ix <- matchMotifs(homer_pwms, se_MEF, genome = 'mm10')

# %%
dev_MEF <- computeDeviations(object = se_MEF, annotations = motif_ix)

# %%
v_MEF <- computeVariability(dev_MEF)

# %% [markdown]
# ## Load motif results for MEF. This results were computed by using the following scripts:
#
# * MEF Ascl1: https://s3.msi.umn.edu/dsouz072/projects/seatac_project/config/seatac_Ascl1_MEF_all_motifs/results.tsv
#
# We used the results of `vae_latent=5`

# %%
remote_MEF_result_file <- 'https://s3.msi.umn.edu/dsouz072/projects/seatac_project/config/seatac_Ascl1_MEF_all_motifs/results.tsv'
local_MEF_result_file <- gsub('https://', './', remote_MEF_result_file)
system(sprintf('wget -cx %s', remote_MEF_result_file))

# %%
x <- read.table(remote_MEF_result_file, header = TRUE, sep = '\t')
sprintf('wget -O %s %s', './MEF.tsv', x$remote_output_file[1]) %>% system()
res_MEF <- read.table('./MEF.tsv', header = FALSE, sep = '\t')

# %%
res <- cbind(res_MEF, group = 'MEF')

# %%
gr <- GRanges(
  seqnames = res[, 1],
  ranges = IRanges(res[, 2], res[, 3]),
  strand = res[, 5],
  pvalue_z = res[, 6],
  padj = res[, 7],
  nucleosome_treatment = res[, 8],
  nucleosome_control = res[, 9],
  log_ratio = res[, 10],
  motif = res[, 11],
  group = res[, 12]
)

# %%
df <- data.frame(
  padj = gr$padj,
  log_ratio = gr$log_ratio,
  motif = gr$motif,
  group = gr$group
) %>%
  mutate(motif = factor(motif, names(homer_pwms))) %>%
  group_by(group, motif) %>%
  summarize(
    up = sum(padj < 0.05 & log_ratio > ARGS[['log_ratio_cutoff']]) / n() * 100,
    down = sum(padj < 0.05 & log_ratio < -ARGS[['log_ratio_cutoff']]) / n() * 100
  ) %>%
  mutate(motif_name = case_when(
    motif == 'Ascl1(bHLH)/NeuralTubes-Ascl1-ChIP-Seq(GSE55840)/Homer' ~ 'Ascl1',
    motif == 'NeuroD1(bHLH)/Islet-NeuroD1-ChIP-Seq(GSE30298)/Homer' ~ 'Neurod1',
    motif == 'Atoh1(bHLH)/Cerebellum-Atoh1-ChIP-Seq(GSE22111)/Homer' ~ 'Atoh1',
    motif == 'Brn2(POU,Homeobox)/NPC-Brn2-ChIP-Seq(GSE35496)/Homer' ~ 'Brn2',
    motif == 'GLI3(Zf)/Limb-GLI3-ChIP-Chip(GSE11077)/Homer' ~ 'Gli3',
    motif == 'Olig2(bHLH)/Neuron-Olig2-ChIP-Seq(GSE30882)/Homer' ~ 'Olig2',
    motif == 'Egr1(Zf)/K562-Egr1-ChIP-Seq(GSE32465)/Homer' ~ 'Egr1',
    motif == 'Sox4(HMG)/proB-Sox4-ChIP-Seq(GSE50066)/Homer' ~ 'Sox4',
    motif == 'c-Myc(bHLH)/mES-cMyc-ChIP-Seq(GSE11431)/Homer' ~ 'c-Myc',
    motif == 'Rbpj1(?)/Panc1-Rbpj1-ChIP-Seq(GSE47459)/Homer' ~ 'RBPJ',
    motif == 'Tcf12(bHLH)/GM12878-Tcf12-ChIP-Seq(GSE32465)/Homer' ~ 'Tcf12', 
    motif == 'Ptf1a(bHLH)/Panc1-Ptf1a-ChIP-Seq(GSE47459)/Homer' ~ 'Ptf1a',
    motif == 'BATF(bZIP)/Th17-BATF-ChIP-Seq(GSE39756)/Homer' ~ 'Batf',
    motif == 'AP-1(bZIP)/ThioMac-PU.1-ChIP-Seq(GSE21512)/Homer' ~ 'AP-1',
    TRUE ~ ''
  ))  %>% 
  cbind(
    chromvar_padj = c(v_MEF$p_value_adj),
    chromvar_diff = c(assays(dev_MEF)$z[, 2] - assays(dev_MEF)$z[, 1])
  ) %>%
  mutate(
    chromvar_log10padj = -log10(chromvar_padj + 1e-100),
    seatac_diff = down - up,
    chromvar_group = case_when(
      chromvar_diff >= 0 ~ 'more_abundant',
      chromvar_diff < 0 ~ 'less_abundant'
    )
  ) %>%
  mutate(motif_group = case_when(
    grepl('bHLH', motif, ignore.case = TRUE) ~ 'bHLH'
  ))
# Out:
# `summarise()` has grouped output by 'group'. You can override using the
# `.groups` argument.

# %% [markdown]
# ## Compare the changes of nucleosome and read density of bHLHs motifs

# %%
options(repr.plot.width = 6, repr.plot.height = 5)
df %>%
  ggplot(aes(x = chromvar_diff, y = seatac_diff, color = motif_group)) +
    geom_hline(yintercept = 0, linetype = 'dashed') +
    geom_vline(xintercept = 0, linetype = 'dashed') +
    geom_point(size = 2) +
    geom_label_repel(aes(label = motif_name), box.padding   = 0.35,  point.padding = 0.5, segment.color = 'grey50', max.overlaps = 1000, size = 5) +
    facet_grid(. ~ group) +
    xlab('chromVAR') + ylab('SeATAC') +
    ggtitle('bHLH motifs')
# Out:
# plot without title

# %% [markdown]
# ## SessionInfo

# %%
sessionInfo()
# Out:
# R version 4.1.2 (2021-11-01)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 18.04.5 LTS
#
# Matrix products: default
# BLAS:   /usr/lib/x86_64-linux-gnu/openblas/libblas.so.3
# LAPACK: /usr/lib/x86_64-linux-gnu/libopenblasp-r0.2.20.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] grid      stats4    stats     graphics  grDevices utils     datasets
# [8] methods   base
#
# other attached packages:
#  [1] ggrepel_0.9.1                      chromVARmotifs_0.2.0
#  [3] motifmatchr_1.16.0                 chromVAR_1.16.0
#  [5] patchwork_1.1.1                    magick_2.7.3
#  [7] circlize_0.4.14                    EnrichedHeatmap_1.24.0
# ...

# %%
Sys.time() - start_time
# Out:
# Time difference of 3.461688 hours
