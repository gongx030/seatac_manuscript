# %% [markdown]
# <a href="https://colab.research.google.com/github/gongx030/seatac_manuscript/blob/main/SeATAC_Etv2_EB_v0_4_0_Vplots_for_and_EBs_Figure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Compare MACS2 and SeATAC for detecting differential V-plots of ATAC-seq data between EBs and Flk1+ EBs at day2.5 post Etv2 induction

# %% [markdown]
# This task runs on SeATAC `v0.4.0`

# %%
start_time <- Sys.time()

# %% [markdown]
# ### Install external packages

# %%
system('apt-get -q install libgsl-dev', intern = TRUE)
# Out:
#  [1] "Reading package lists..."
#  [2] "Building dependency tree..."
#  [3] "Reading state information..."
#  [4] "The following additional packages will be installed:"
#  [5] "  libgsl23 libgslcblas0"
#  [6] "Suggested packages:"
#  [7] "  gsl-ref-psdoc | gsl-doc-pdf | gsl-doc-info | gsl-ref-html"
#  [8] "The following NEW packages will be installed:"
#  [9] "  libgsl-dev libgsl23 libgslcblas0"
# [10] "0 upgraded, 3 newly installed, 0 to remove and 39 not upgraded."
# [11] "Need to get 1,926 kB of archives."
# [12] "After this operation, 9,474 kB of additional disk space will be used."
# [13] "Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgslcblas0 amd64 2.4+dfsg-6 [79.7 kB]"
# [14] "Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgsl23 amd64 2.4+dfsg-6 [823 kB]"
# [15] "Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgsl-dev amd64 2.4+dfsg-6 [1,023 kB]"
# [16] "Fetched 1,926 kB in 0s (4,248 kB/s)"
# [17] "Selecting previously unselected package libgslcblas0:amd64.\r"
# [18] "(Reading database ... \r(Reading database ... 5%\r(Reading database ... 10%\r(Reading database ... 15%\r(Reading database ... 20%\r(Reading database ... 25%\r(Reading database ... 30%\r(Reading database ... 35%\r(Reading database ... 40%\r(Reading database ... 45%\r(Reading database ... 50%\r(Reading database ... 55%\r(Reading database ... 60%\r(Reading database ... 65%\r(Reading database ... 70%\r(Reading database ... 75%\r(Reading database ... 80%\r(Reading database ... 85%\r(Reading database ... 90%\r(Reading database ... 95%\r(Reading database ... 100%\r(Reading database ... 155335 files and directories currently installed.)\r"
# [19] "Preparing to unpack .../libgslcblas0_2.4+dfsg-6_amd64.deb ...\r"
# [20] "Unpacking libgslcblas0:amd64 (2.4+dfsg-6) ...\r"
# [21] "Selecting previously unselected package libgsl23:amd64.\r"
# [22] "Preparing to unpack .../libgsl23_2.4+dfsg-6_amd64.deb ...\r"
# [23] "Unpacking libgsl23:amd64 (2.4+dfsg-6) ...\r"
# [24] "Selecting previously unselected package libgsl-dev.\r"
# [25] "Preparing to unpack .../libgsl-dev_2.4+dfsg-6_amd64.deb ...\r"
# [26] "Unpacking libgsl-dev (2.4+dfsg-6) ...\r"
# [27] "Setting up libgslcblas0:amd64 (2.4+dfsg-6) ...\r"
# [28] "Setting up libgsl23:amd64 (2.4+dfsg-6) ...\r"
# [29] "Setting up libgsl-dev (2.4+dfsg-6) ...\r"
# [30] "Processing triggers for man-db (2.8.3-2ubuntu0.1) ...\r"
# [31] "Processing triggers for libc-bin (2.27-3ubuntu1.3) ...\r"
# [32] "/sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link\r"
# [33] "\r"

# %%
system('apt-get install libcairo2-dev', intern = TRUE) # for Cairo package that is required by ComplexHeatmap package
# Out:
#  [1] "Reading package lists..."
#  [2] "Building dependency tree..."
#  [3] "Reading state information..."
#  [4] "The following additional packages will be installed:"
#  [5] "  libcairo-script-interpreter2 libpixman-1-dev libxcb-shm0-dev"
#  [6] "Suggested packages:"
#  [7] "  libcairo2-doc"
#  [8] "The following NEW packages will be installed:"
#  [9] "  libcairo-script-interpreter2 libcairo2-dev libpixman-1-dev libxcb-shm0-dev"
# [10] "0 upgraded, 4 newly installed, 0 to remove and 39 not upgraded."
# [11] "Need to get 930 kB of archives."
# [12] "After this operation, 3,986 kB of additional disk space will be used."
# [13] "Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo-script-interpreter2 amd64 1.15.10-2ubuntu0.1 [53.5 kB]"
# [14] "Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpixman-1-dev amd64 0.34.0-2 [244 kB]"
# [15] "Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-shm0-dev amd64 1.13-2~ubuntu18.04 [6,684 B]"
# [16] "Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo2-dev amd64 1.15.10-2ubuntu0.1 [626 kB]"
# [17] "Fetched 930 kB in 1s (1,008 kB/s)"
# [18] "Selecting previously unselected package libcairo-script-interpreter2:amd64.\r"
# [19] "(Reading database ... \r(Reading database ... 5%\r(Reading database ... 10%\r(Reading database ... 15%\r(Reading database ... 20%\r(Reading database ... 25%\r(Reading database ... 30%\r(Reading database ... 35%\r(Reading database ... 40%\r(Reading database ... 45%\r(Reading database ... 50%\r(Reading database ... 55%\r(Reading database ... 60%\r(Reading database ... 65%\r(Reading database ... 70%\r(Reading database ... 75%\r(Reading database ... 80%\r(Reading database ... 85%\r(Reading database ... 90%\r(Reading database ... 95%\r(Reading database ... 100%\r(Reading database ... 155607 files and directories currently installed.)\r"
# [20] "Preparing to unpack .../libcairo-script-interpreter2_1.15.10-2ubuntu0.1_amd64.deb ...\r"
# [21] "Unpacking libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...\r"
# [22] "Selecting previously unselected package libpixman-1-dev:amd64.\r"
# [23] "Preparing to unpack .../libpixman-1-dev_0.34.0-2_amd64.deb ...\r"
# [24] "Unpacking libpixman-1-dev:amd64 (0.34.0-2) ...\r"
# [25] "Selecting previously unselected package libxcb-shm0-dev:amd64.\r"
# [26] "Preparing to unpack .../libxcb-shm0-dev_1.13-2~ubuntu18.04_amd64.deb ...\r"
# [27] "Unpacking libxcb-shm0-dev:amd64 (1.13-2~ubuntu18.04) ...\r"
# [28] "Selecting previously unselected package libcairo2-dev:amd64.\r"
# [29] "Preparing to unpack .../libcairo2-dev_1.15.10-2ubuntu0.1_amd64.deb ...\r"
# [30] "Unpacking libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...\r"
# [31] "Setting up libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...\r"
# [32] "Setting up libxcb-shm0-dev:amd64 (1.13-2~ubuntu18.04) ...\r"
# [33] "Setting up libpixman-1-dev:amd64 (0.34.0-2) ...\r"
# [34] "Setting up libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...\r"
# [35] "Processing triggers for libc-bin (2.27-3ubuntu1.3) ...\r"
# [36] "/sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link\r"
# [37] "\r"

# %% [markdown]
# ### Install R packages from CRAN

# %%
install.packages('BiocManager')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
required_packages <- c(
  "GenomicAlignments",
  'BSgenome.Mmusculus.UCSC.mm10',
  'motifmatchr',
  'uwot',
  'igraph',
  'VennDiagram',
  'patchwork'
 )

# %%
missing_packages <- required_packages[!required_packages %in% rownames(installed.packages())]
if (length(missing_packages) > 0){
    BiocManager::install(missing_packages)
}
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# '?repositories' for details
#
# replacement repositories:
#     CRAN: https://cran.rstudio.com
#
#
# Bioconductor version 3.14 (BiocManager 1.30.16), R 4.1.2 (2021-11-01)
#
# Installing package(s) 'BiocVersion', 'GenomicAlignments',
#   'BSgenome.Mmusculus.UCSC.mm10', 'motifmatchr', 'uwot', 'igraph',
#   'VennDiagram', 'patchwork'
#
# also installing the dependencies ‘rjson’, ‘plyr’, ‘pracma’, ‘AnnotationDbi’, ‘xtable’, ‘R.oo’, ‘R.methodsS3’, ‘png’, ‘BiocIO’, ‘restfulr’, ‘reshape2’, ‘poweRlaw’, ‘annotate’, ‘GO.db’, ‘R.utils’, ‘KEGGREST’, ‘plogr’, ‘formatR’, ‘RCurl’, ‘GenomeInfoDbData’, ‘XVector’, ‘MatrixGenerics’, ‘Biobase’, ‘DelayedArray’, ‘zlibbioc’, ‘bitops’, ‘Rhtslib’, ‘snow’, ‘BH’, ‘rtracklayer’, ‘matrixStats’, ‘caTools’, ‘CNEr’, ‘DirichletMultinomial’, ‘gtools’, ‘RSQLite’, ‘seqLogo’, ‘TFMPvalue’, ‘XML’, ‘RcppEigen’, ‘sitmo’, ‘lambda.r’, ‘futile.options’, ‘BiocGenerics’, ‘S4Vectors’, ‘IRanges’, ‘GenomeInfoDb’, ‘GenomicRanges’, ‘SummarizedExperiment’, ‘Biostrings’, ‘Rsamtools’, ‘BiocParallel’, ‘BSgenome’, ‘TFBSTools’, ‘RcppArmadillo’, ‘FNN’, ‘RSpectra’, ‘RcppAnnoy’, ‘irlba’, ‘RcppProgress’, ‘dqrng’, ‘futile.logger’
#
#
# Old packages: 'commonmark', 'desc', 'openssl', 'Rcpp', 'rlang', 'rmarkdown',
#   'uuid', 'waldo', 'withr', 'xfun', 'survival'

# %%
library(devtools)
# Out:
# Loading required package: usethis

# %% [markdown]
# ### Install R packages from github

# %%
install_github("GreenleafLab/chromVARmotifs")
# Out:
# Downloading GitHub repo GreenleafLab/chromVARmotifs@HEAD
# Rcpp    (1.0.8 -> 1.0.8.3) [CRAN]
# rlang   (1.0.1 -> 1.0.2  ) [CRAN]
# openssl (1.4.6 -> 2.0.0  ) [CRAN]
# withr   (2.4.3 -> 2.5.0  ) [CRAN]
# Installing 4 packages: Rcpp, rlang, openssl, withr
#
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# * checking for file ‘/tmp/RtmpMkGb8x/remotes513623a89d/GreenleafLab-chromVARmotifs-38bed55/DESCRIPTION’ ... OK
# * preparing ‘chromVARmotifs’:
# * checking DESCRIPTION meta-information ... OK
# * checking for LF line-endings in source and make files and shell scripts
# * checking for empty or unneeded directories
# * building ‘chromVARmotifs_0.2.0.tar.gz’
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %% [markdown]
# ### Install `seatac` from github

# %%
install_github('gongx030/seatac', quiet = FALSE, ref = 'v0.4.0') # install from the branch v0.4.0
devtools::reload(pkgload::inst("seatac"))
library(seatac)
# Out:
# Downloading GitHub repo gongx030/seatac@v0.4.0
# tfautograph  (NA -> 0.3.2 ) [CRAN]
# config       (NA -> 0.3.1 ) [CRAN]
# here         (NA -> 1.0.1 ) [CRAN]
# RcppTOML     (NA -> 0.1.7 ) [CRAN]
# zeallot      (NA -> 0.1.0 ) [CRAN]
# tfruns       (NA -> 1.5.0 ) [CRAN]
# tensorflow   (NA -> 2.8.0 ) [CRAN]
# reticulate   (NA -> 1.24  ) [CRAN]
# keras        (NA -> 2.8.0 ) [CRAN]
# abind        (NA -> 1.4-5 ) [CRAN]
# gplots       (NA -> 3.1.1 ) [CRAN]
# tfdatasets   (NA -> 2.7.0 ) [CRAN]
# tfprobabi... (NA -> 0.15.0) [CRAN]
# Installing 13 packages: tfautograph, config, here, RcppTOML, zeallot, tfruns, tensorflow, reticulate, keras, abind, gplots, tfdatasets, tfprobability
#
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# * checking for file ‘/tmp/RtmpMkGb8x/remotes51c8cc327/gongx030-seatac-55f9f36/DESCRIPTION’ ... OK
# * preparing ‘seatac’:
# * checking DESCRIPTION meta-information ... OK
# * checking for LF line-endings in source and make files and shell scripts
# * checking for empty or unneeded directories
# Omitted ‘LazyData’ from DESCRIPTION
# * building ‘seatac_0.4.0-010.tar.gz’
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: tensorflow
#
# Loading required package: tfprobability
#
# Loading required package: tfdatasets
#
# Loading required package: GenomicRanges
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘Biobase’
#
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
#
#
# Attaching package: ‘seatac’
#
#
# The following object is masked from ‘package:tfdatasets’:
#
#     fit
#
#
# The following object is masked from ‘package:stats’:
#
#     predict

# %% [markdown]
# ### Load R packages

# %%
library(BSgenome.Mmusculus.UCSC.mm10)
library(dplyr)
library(motifmatchr)
library(chromVARmotifs)
library(igraph)
library(VennDiagram)
library(ggplot2)
library(patchwork)
# Out:
# Loading required package: BSgenome
#
# Loading required package: Biostrings
#
# Loading required package: XVector
#
#
# Attaching package: ‘Biostrings’
#
#
# The following object is masked from ‘package:base’:
#
#     strsplit
#
#
# Loading required package: rtracklayer
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:Biostrings’:
#
#     collapse, intersect, setdiff, setequal, union
#
#
# The following object is masked from ‘package:XVector’:
#
#     slice
#
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
#
# The following object is masked from ‘package:matrixStats’:
#
#     count
#
#
# The following objects are masked from ‘package:GenomicRanges’:
#
#     intersect, setdiff, union
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
#
#
# Attaching package: ‘igraph’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     as_data_frame, groups, union
#
#
# The following objects are masked from ‘package:rtracklayer’:
#
#     blocks, path
#
#
# The following object is masked from ‘package:Biostrings’:
#
#     union
#
#
# The following object is masked from ‘package:XVector’:
#
#     path
#
#
# The following object is masked from ‘package:GenomicRanges’:
#
#     union
#
#
# The following object is masked from ‘package:IRanges’:
#
#     union
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     union
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     normalize, path, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union
#
#
# Loading required package: grid
#
#
# Attaching package: ‘grid’
#
#
# The following object is masked from ‘package:Biostrings’:
#
#     pattern
#
#
# Loading required package: futile.logger

# %% [markdown]
# ### TensorFlow setup

# %%
gpus <- tf$config$list_physical_devices('GPU')
for (gpu in gpus){
  tf$config$experimental$set_memory_growth(gpu, TRUE)
}
logical_gpus <- tf$config$experimental$list_logical_devices('GPU')
sprintf('Physical GPUs: %d', length(gpus)) %>% message()
sprintf('Logical GPUs: %d', length(logical_gpus)) %>% message()
# Out:
# Loaded Tensorflow version 2.8.0
#
# Physical GPUs: 1
#
# Logical GPUs: 1

# %%
Sys.time() - start_time
# Out:
# Time difference of 30.61412 mins

# %% [markdown]
# ## Parameters

# %%
ARGS <- list(
  bin_size = 5L,
  fragment_size_range_max = 640L,
  fragment_size_interval = 20L,
  window_size = 1000L,
  block_size = 640L,
  sliding_step = 20L,
  min_reads = 10L,

  vae_num_peaks = 5000L,
  vae_latent = c(5L),
  vae_filters0 = c(128L),
  vae_filters = c(32L),
  vae_downsample_layers = 4L,
  vae_upsample_layers = 4L,
  vae_base_learning_rate = c(1e-2),
  vae_epochs = 200L,
  vae_beta_schedule_method = c('constant'),
  vae_beta0 = 1,
  vae_batch_size = c(128L),
  vae_warmup_ratio = 0.1,
  padjusted_cutoff = 0.05,
  log_ratio_cutoff = 0.1,
  center_width = 100L # the center width
)

# %% [markdown]
# #EBs

# %% [markdown]
# ## Load data

# %%
remote_bam_files = c(
 EB_NoDox_D25 = 'https://s3.msi.umn.edu/gongx030/datasets/dataset=Etv2ATAC_version=20190228b/EB_NoDox_D25.bam',
  EB_Dox_D25_Flk1pos = 'https://s3.msi.umn.edu/gongx030/datasets/dataset=Etv2ATAC_version=20190228b/EB_Dox_D25_Flk1pos.bam'
)
for (f in remote_bam_files){
  system(sprintf('wget -cx %s', f))
}
local_bam_files <- gsub('https://', './', remote_bam_files)

# %%
remote_bed_files <- gsub('.bam', '_summits.bed', remote_bam_files)
for (f in remote_bed_files){
  system(sprintf('wget -cx %s', f))
}
local_bed_files <- gsub('https://', './', remote_bed_files)

# %% [markdown]
# ### Read V-plots

# %%
gr0 <- lapply(local_bed_files, function(bed_file){
  peaks <- read.table(bed_file, header = FALSE, sep = '\t')
  peaks <- GRanges(seqnames = peaks[, 1], range = IRanges(start = peaks[, 2], end = peaks[, 3]))
  peaks <- resize(peaks, fix = 'center', width = 200L)
  peaks
}) %>%
  GRangesList() %>%
  coverage() %>%
  IRanges::slice(lower = 1, rangesOnly = TRUE) %>%
  GRanges() %>%
  resize(fix = 'center', width = ARGS[['window_size']])
gr0 <- gr0[!seqnames(gr0) %in% c('chrM', 'chrY')]
gr <- slidingWindows(gr0, width = ARGS[['block_size']], step = ARGS[['sliding_step']]) %>% unlist()
set.seed(1L); gr <- sample(gr, ARGS[['vae_num_peaks']])
counts <- count_reads(gr, local_bam_files, genome = BSgenome.Mmusculus.UCSC.mm10,  fragment_size_range = c(0, ARGS[['fragment_size_range_max']]))
# Out:
# validate_bam | indexing bam files: ./s3.msi.umn.edu/gongx030/datasets/dataset=Etv2ATAC_version=20190228b/EB_NoDox_D25.bam
#
# read_bam | reading ./s3.msi.umn.edu/gongx030/datasets/dataset=Etv2ATAC_version=20190228b/EB_NoDox_D25.bam
#
# validate_bam | indexing bam files: ./s3.msi.umn.edu/gongx030/datasets/dataset=Etv2ATAC_version=20190228b/EB_Dox_D25_Flk1pos.bam
#
# read_bam | reading ./s3.msi.umn.edu/gongx030/datasets/dataset=Etv2ATAC_version=20190228b/EB_Dox_D25_Flk1pos.bam

# %%
valid <- rowSums(counts >= ARGS[['min_reads']]) == length(local_bam_files)
gr <- gr[valid]
sprintf('number of training peaks for VaeModel: %d', length(gr)) %>% message()
x <- read_vplot(gr, filenames = local_bam_files, genome = BSgenome.Mmusculus.UCSC.mm10, bin_size = ARGS[['bin_size']], fragment_size_range = c(0, ARGS[['fragment_size_range_max']]), fragment_size_interval = ARGS[['fragment_size_interval']])
# Out:
# number of training peaks for VaeModel: 4578
#
# read_bam | reading ./s3.msi.umn.edu/gongx030/datasets/dataset=Etv2ATAC_version=20190228b/EB_NoDox_D25.bam
#
# read_bam | reading ./s3.msi.umn.edu/gongx030/datasets/dataset=Etv2ATAC_version=20190228b/EB_Dox_D25_Flk1pos.bam

# %% [markdown]
# ### Training VAE model for V-plots

# %% [markdown]
# As of 1/20/2022, Colab had errors on the first run. Run the cell again will resolve the issue.

# %%
model <- new('VaeModel', model = VaeModel(
  n_samples = dim(x)['sample'],
  latent_dim = ARGS[['vae_latent']],
  block_size = ARGS[['block_size']],
  bin_size = ARGS[['bin_size']],
  filters0 = ARGS[['vae_filters0']],
  filters = ARGS[['vae_filters']],
  upsample_layers = ARGS[['vae_upsample_layers']],
  downsample_layers = ARGS[['vae_downsample_layers']],
  fragment_size_range  = c(0, ARGS[['fragment_size_range_max']]),
  fragment_size_interval = ARGS[['fragment_size_interval']]
))
lr <- WarmUpAndCosineDecay(
  base_learning_rate = ARGS[['vae_base_learning_rate']],
  num_examples = nrow(x),
  batch_size = ARGS[['vae_batch_size']],
  epochs = ARGS[['vae_epochs']],
  warmup_epochs = as.integer(ARGS[['vae_epochs']] * ARGS[['vae_warmup_ratio']])
)
beta <- beta_schedule(
  method = ARGS[['vae_beta_schedule_method']],
  beta0 = ARGS[['vae_beta0']],
  epochs = ARGS[['vae_epochs']]
)
d <- model %>% prepare_data(x)
d <- d %>% tensor_slices_dataset()
model <- model %>% fit(d, batch_size =  ARGS[['vae_batch_size']], epochs = ARGS[['vae_epochs']], learning_rate = lr, compile = TRUE, beta = beta)
# Out:
# epoch=     1/   200 | beta=1.000e+00 | loss= 3424.2704061 | loss_reconstruction= 3423.7436591 | loss_kl=    0.5267453
#
# epoch=     2/   200 | beta=1.000e+00 | loss= 2773.8633965 | loss_reconstruction= 2772.7438694 | loss_kl=    1.1195337
#
# epoch=     3/   200 | beta=1.000e+00 | loss= 2429.5399170 | loss_reconstruction= 2427.8167114 | loss_kl=    1.7232388
#
# epoch=     4/   200 | beta=1.000e+00 | loss= 2020.7612203 | loss_reconstruction= 2019.6969469 | loss_kl=    1.0642610
#
# epoch=     5/   200 | beta=1.000e+00 | loss= 1482.9853244 | loss_reconstruction= 1482.3152466 | loss_kl=    0.6700701
#
# epoch=     6/   200 | beta=1.000e+00 | loss=  952.8778347 | loss_reconstruction=  952.5626967 | loss_kl=    0.3151358
#
# epoch=     7/   200 | beta=1.000e+00 | loss=  603.4906040 | loss_reconstruction=  603.3829371 | loss_kl=    0.1076737
#
# epoch=     8/   200 | beta=1.000e+00 | loss=  438.1127633 | loss_reconstruction=  437.9914110 | loss_kl=    0.1213526
#
# epoch=     9/   200 | beta=1.000e+00 | loss=  367.6160414 | loss_reconstruction=  366.8831100 | loss_kl=    0.7329322
#
# epoch=    10/   200 | beta=1.000e+00 | loss=  335.2164459 | loss_reconstruction=  333.8680827 | loss_kl=    1.3483623
#
# epoch=    11/   200 | beta=1.000e+00 | loss=  319.5337448 | loss_reconstruction=  317.5996017 | loss_kl=    1.9341442
#
# epoch=    12/   200 | beta=1.000e+00 | loss=  310.9893646 | loss_reconstruction=  308.1518546 | loss_kl=    2.8375087
#
# epoch=    13/   200 | beta=1.000e+00 | loss=  303.6932517 | loss_reconstruction=  299.9125426 | loss_kl=    3.7807093
#
# epoch=    14/   200 | beta=1.000e+00 | loss=  298.0708143 | loss_reconstruction=  293.5246574 | loss_kl=    4.5461570
#
# epoch=    15/   200 | beta=1.000e+00 | loss=  294.7410172 | loss_reconstruction=  289.7743225 | loss_kl=    4.9666961
#
# epoch=    16/   200 | beta=1.000e+00 | loss=  293.7242512 | loss_reconstruction=  288.5873612 | loss_kl=    5.1368905
#
# epoch=    17/   200 | beta=1.000e+00 | loss=  292.8027984 | loss_reconstruction=  287.6513163 | loss_kl=    5.1514793
#
# epoch=    18/   200 | beta=1.000e+00 | loss=  291.4805777 | loss_reconstruction=  286.1547063 | loss_kl=    5.3258701
#
# epoch=    19/   200 | beta=1.000e+00 | loss=  290.8708060 | loss_reconstruction=  285.4375593 | loss_kl=    5.4332456
#
# epoch=    20/   200 | beta=1.000e+00 | loss=  290.7318170 | loss_reconstruction=  285.2868186 | loss_kl=    5.4449995
#
# epoch=    21/   200 | beta=1.000e+00 | loss=  289.8723407 | loss_reconstruction=  284.2955725 | loss_kl=    5.5767681
#
# epoch=    22/   200 | beta=1.000e+00 | loss=  289.2076068 | loss_reconstruction=  283.5535240 | loss_kl=    5.6540810
#
# epoch=    23/   200 | beta=1.000e+00 | loss=  289.0933702 | loss_reconstruction=  283.4322230 | loss_kl=    5.6611455
#
# epoch=    24/   200 | beta=1.000e+00 | loss=  288.7830094 | loss_reconstruction=  283.0422952 | loss_kl=    5.7407130
#
# epoch=    25/   200 | beta=1.000e+00 | loss=  288.6710091 | loss_reconstruction=  282.8747694 | loss_kl=    5.7962412
#
# epoch=    26/   200 | beta=1.000e+00 | loss=  288.2699229 | loss_reconstruction=  282.4362242 | loss_kl=    5.8336963
#
# epoch=    27/   200 | beta=1.000e+00 | loss=  287.8477300 | loss_reconstruction=  281.9557287 | loss_kl=    5.8920025
#
# epoch=    28/   200 | beta=1.000e+00 | loss=  287.9890285 | loss_reconstruction=  282.0642582 | loss_kl=    5.9247704
#
# epoch=    29/   200 | beta=1.000e+00 | loss=  287.8559897 | loss_reconstruction=  281.9109942 | loss_kl=    5.9449945
#
# epoch=    30/   200 | beta=1.000e+00 | loss=  287.6045926 | loss_reconstruction=  281.6473838 | loss_kl=    5.9572084
#
# epoch=    31/   200 | beta=1.000e+00 | loss=  287.4351196 | loss_reconstruction=  281.4201495 | loss_kl=    6.0149664
#
# epoch=    32/   200 | beta=1.000e+00 | loss=  287.4433954 | loss_reconstruction=  281.4605849 | loss_kl=    5.9828096
#
# epoch=    33/   200 | beta=1.000e+00 | loss=  287.2282689 | loss_reconstruction=  281.1798715 | loss_kl=    6.0483973
#
# epoch=    34/   200 | beta=1.000e+00 | loss=  287.2787306 | loss_reconstruction=  281.2403221 | loss_kl=    6.0384085
#
# epoch=    35/   200 | beta=1.000e+00 | loss=  287.1743673 | loss_reconstruction=  281.0710725 | loss_kl=    6.1032930
#
# epoch=    36/   200 | beta=1.000e+00 | loss=  287.0996967 | loss_reconstruction=  281.0122884 | loss_kl=    6.0874082
#
# epoch=    37/   200 | beta=1.000e+00 | loss=  286.7404467 | loss_reconstruction=  280.6761801 | loss_kl=    6.0642673
#
# epoch=    38/   200 | beta=1.000e+00 | loss=  286.6578267 | loss_reconstruction=  280.5220375 | loss_kl=    6.1357889
#
# epoch=    39/   200 | beta=1.000e+00 | loss=  286.7226719 | loss_reconstruction=  280.6047300 | loss_kl=    6.1179413
#
# epoch=    40/   200 | beta=1.000e+00 | loss=  286.6185413 | loss_reconstruction=  280.4635349 | loss_kl=    6.1550068
#
# epoch=    41/   200 | beta=1.000e+00 | loss=  286.7201992 | loss_reconstruction=  280.5468377 | loss_kl=    6.1733579
#
# epoch=    42/   200 | beta=1.000e+00 | loss=  286.3785812 | loss_reconstruction=  280.1751934 | loss_kl=    6.2033890
#
# epoch=    43/   200 | beta=1.000e+00 | loss=  286.4435370 | loss_reconstruction=  280.2457572 | loss_kl=    6.1977805
#
# epoch=    44/   200 | beta=1.000e+00 | loss=  286.5402968 | loss_reconstruction=  280.3349016 | loss_kl=    6.2053948
#
# epoch=    45/   200 | beta=1.000e+00 | loss=  286.2436341 | loss_reconstruction=  280.0108685 | loss_kl=    6.2327638
#
# epoch=    46/   200 | beta=1.000e+00 | loss=  286.1911837 | loss_reconstruction=  279.9205818 | loss_kl=    6.2706005
#
# epoch=    47/   200 | beta=1.000e+00 | loss=  286.1992251 | loss_reconstruction=  279.9717793 | loss_kl=    6.2274439
#
# epoch=    48/   200 | beta=1.000e+00 | loss=  285.9930322 | loss_reconstruction=  279.7061030 | loss_kl=    6.2869301
#
# epoch=    49/   200 | beta=1.000e+00 | loss=  286.0596559 | loss_reconstruction=  279.7761718 | loss_kl=    6.2834840
#
# epoch=    50/   200 | beta=1.000e+00 | loss=  286.2550850 | loss_reconstruction=  279.9660806 | loss_kl=    6.2890042
#
# epoch=    51/   200 | beta=1.000e+00 | loss=  286.0176315 | loss_reconstruction=  279.7023265 | loss_kl=    6.3153046
#
# epoch=    52/   200 | beta=1.000e+00 | loss=  285.7852181 | loss_reconstruction=  279.5128937 | loss_kl=    6.2723244
#
# epoch=    53/   200 | beta=1.000e+00 | loss=  285.9738778 | loss_reconstruction=  279.6253883 | loss_kl=    6.3484889
#
# epoch=    54/   200 | beta=1.000e+00 | loss=  285.9577170 | loss_reconstruction=  279.5972324 | loss_kl=    6.3604849
#
# epoch=    55/   200 | beta=1.000e+00 | loss=  285.8146994 | loss_reconstruction=  279.4560538 | loss_kl=    6.3586459
#
# epoch=    56/   200 | beta=1.000e+00 | loss=  285.6740515 | loss_reconstruction=  279.3317795 | loss_kl=    6.3422691
#
# epoch=    57/   200 | beta=1.000e+00 | loss=  285.4616530 | loss_reconstruction=  279.0622287 | loss_kl=    6.3994256
#
# epoch=    58/   200 | beta=1.000e+00 | loss=  285.4707616 | loss_reconstruction=  279.0624063 | loss_kl=    6.4083534
#
# epoch=    59/   200 | beta=1.000e+00 | loss=  285.6052013 | loss_reconstruction=  279.1741952 | loss_kl=    6.4310085
#
# epoch=    60/   200 | beta=1.000e+00 | loss=  285.3569921 | loss_reconstruction=  278.9348950 | loss_kl=    6.4220964
#
# epoch=    61/   200 | beta=1.000e+00 | loss=  285.4350857 | loss_reconstruction=  279.0373620 | loss_kl=    6.3977249
#
# epoch=    62/   200 | beta=1.000e+00 | loss=  285.5644824 | loss_reconstruction=  279.1224721 | loss_kl=    6.4420097
#
# epoch=    63/   200 | beta=1.000e+00 | loss=  285.2829560 | loss_reconstruction=  278.8417960 | loss_kl=    6.4411606
#
# epoch=    64/   200 | beta=1.000e+00 | loss=  285.2252647 | loss_reconstruction=  278.7585161 | loss_kl=    6.4667470
#
# epoch=    65/   200 | beta=1.000e+00 | loss=  285.1075507 | loss_reconstruction=  278.6326353 | loss_kl=    6.4749175
#
# epoch=    66/   200 | beta=1.000e+00 | loss=  285.3485074 | loss_reconstruction=  278.8821203 | loss_kl=    6.4663862
#
# epoch=    67/   200 | beta=1.000e+00 | loss=  285.9486037 | loss_reconstruction=  279.5044776 | loss_kl=    6.4441253
#
# epoch=    68/   200 | beta=1.000e+00 | loss=  285.2973684 | loss_reconstruction=  278.8620767 | loss_kl=    6.4352925
#
# epoch=    69/   200 | beta=1.000e+00 | loss=  285.0652534 | loss_reconstruction=  278.5253843 | loss_kl=    6.5398691
#
# epoch=    70/   200 | beta=1.000e+00 | loss=  284.8881993 | loss_reconstruction=  278.3290842 | loss_kl=    6.5591145
#
# epoch=    71/   200 | beta=1.000e+00 | loss=  285.1961539 | loss_reconstruction=  278.6603194 | loss_kl=    6.5358353
#
# epoch=    72/   200 | beta=1.000e+00 | loss=  284.9966558 | loss_reconstruction=  278.4405433 | loss_kl=    6.5561111
#
# epoch=    73/   200 | beta=1.000e+00 | loss=  284.8141060 | loss_reconstruction=  278.2751422 | loss_kl=    6.5389627
#
# epoch=    74/   200 | beta=1.000e+00 | loss=  284.5582335 | loss_reconstruction=  278.0086560 | loss_kl=    6.5495780
#
# epoch=    75/   200 | beta=1.000e+00 | loss=  284.8270387 | loss_reconstruction=  278.2341580 | loss_kl=    6.5928813
#
# epoch=    76/   200 | beta=1.000e+00 | loss=  284.7843403 | loss_reconstruction=  278.1809281 | loss_kl=    6.6034114
#
# epoch=    77/   200 | beta=1.000e+00 | loss=  284.7891981 | loss_reconstruction=  278.1750348 | loss_kl=    6.6141638
#
# epoch=    78/   200 | beta=1.000e+00 | loss=  284.4730606 | loss_reconstruction=  277.8684468 | loss_kl=    6.6046135
#
# epoch=    79/   200 | beta=1.000e+00 | loss=  284.4243401 | loss_reconstruction=  277.7933027 | loss_kl=    6.6310383
#
# epoch=    80/   200 | beta=1.000e+00 | loss=  284.4721455 | loss_reconstruction=  277.8319066 | loss_kl=    6.6402389
#
# epoch=    81/   200 | beta=1.000e+00 | loss=  284.4823583 | loss_reconstruction=  277.8684781 | loss_kl=    6.6138814
#
# epoch=    82/   200 | beta=1.000e+00 | loss=  284.2222748 | loss_reconstruction=  277.5272035 | loss_kl=    6.6950694
#
# epoch=    83/   200 | beta=1.000e+00 | loss=  284.2713326 | loss_reconstruction=  277.6085048 | loss_kl=    6.6628294
#
# epoch=    84/   200 | beta=1.000e+00 | loss=  284.5852093 | loss_reconstruction=  277.8879734 | loss_kl=    6.6972345
#
# epoch=    85/   200 | beta=1.000e+00 | loss=  284.1286736 | loss_reconstruction=  277.4572843 | loss_kl=    6.6713860
#
# epoch=    86/   200 | beta=1.000e+00 | loss=  284.2059085 | loss_reconstruction=  277.5348422 | loss_kl=    6.6710641
#
# epoch=    87/   200 | beta=1.000e+00 | loss=  284.0622520 | loss_reconstruction=  277.3284857 | loss_kl=    6.7337657
#
# epoch=    88/   200 | beta=1.000e+00 | loss=  283.8864271 | loss_reconstruction=  277.1532016 | loss_kl=    6.7332261
#
# epoch=    89/   200 | beta=1.000e+00 | loss=  284.0254839 | loss_reconstruction=  277.2601551 | loss_kl=    6.7653290
#
# epoch=    90/   200 | beta=1.000e+00 | loss=  284.0015937 | loss_reconstruction=  277.2502382 | loss_kl=    6.7513557
#
# epoch=    91/   200 | beta=1.000e+00 | loss=  283.8709301 | loss_reconstruction=  277.1259032 | loss_kl=    6.7450250
#
# epoch=    92/   200 | beta=1.000e+00 | loss=  283.7329178 | loss_reconstruction=  276.9398982 | loss_kl=    6.7930215
#
# epoch=    93/   200 | beta=1.000e+00 | loss=  283.7147191 | loss_reconstruction=  276.9812118 | loss_kl=    6.7335069
#
# epoch=    94/   200 | beta=1.000e+00 | loss=  283.6112544 | loss_reconstruction=  276.7964452 | loss_kl=    6.8148113
#
# epoch=    95/   200 | beta=1.000e+00 | loss=  283.5784145 | loss_reconstruction=  276.7820786 | loss_kl=    6.7963344
#
# epoch=    96/   200 | beta=1.000e+00 | loss=  283.7891265 | loss_reconstruction=  277.0003645 | loss_kl=    6.7887652
#
# epoch=    97/   200 | beta=1.000e+00 | loss=  283.7530429 | loss_reconstruction=  276.9202084 | loss_kl=    6.8328331
#
# epoch=    98/   200 | beta=1.000e+00 | loss=  283.4671063 | loss_reconstruction=  276.5826920 | loss_kl=    6.8844129
#
# epoch=    99/   200 | beta=1.000e+00 | loss=  283.4314457 | loss_reconstruction=  276.6188901 | loss_kl=    6.8125563
#
# epoch=   100/   200 | beta=1.000e+00 | loss=  283.3417532 | loss_reconstruction=  276.4553566 | loss_kl=    6.8863966
#
# epoch=   101/   200 | beta=1.000e+00 | loss=  283.3435775 | loss_reconstruction=  276.4541211 | loss_kl=    6.8894587
#
# epoch=   102/   200 | beta=1.000e+00 | loss=  283.4319801 | loss_reconstruction=  276.5699459 | loss_kl=    6.8620338
#
# epoch=   103/   200 | beta=1.000e+00 | loss=  283.3273188 | loss_reconstruction=  276.4545525 | loss_kl=    6.8727682
#
# epoch=   104/   200 | beta=1.000e+00 | loss=  283.2909389 | loss_reconstruction=  276.3773240 | loss_kl=    6.9136154
#
# epoch=   105/   200 | beta=1.000e+00 | loss=  283.1190431 | loss_reconstruction=  276.1962399 | loss_kl=    6.9228027
#
# epoch=   106/   200 | beta=1.000e+00 | loss=  283.0298576 | loss_reconstruction=  276.1014294 | loss_kl=    6.9284316
#
# epoch=   107/   200 | beta=1.000e+00 | loss=  282.9486194 | loss_reconstruction=  276.0138173 | loss_kl=    6.9348025
#
# epoch=   108/   200 | beta=1.000e+00 | loss=  283.1192254 | loss_reconstruction=  276.1804127 | loss_kl=    6.9388145
#
# epoch=   109/   200 | beta=1.000e+00 | loss=  283.0479448 | loss_reconstruction=  276.0471912 | loss_kl=    7.0007553
#
# epoch=   110/   200 | beta=1.000e+00 | loss=  282.8636856 | loss_reconstruction=  275.8701926 | loss_kl=    6.9934959
#
# epoch=   111/   200 | beta=1.000e+00 | loss=  282.7544356 | loss_reconstruction=  275.7866033 | loss_kl=    6.9678310
#
# epoch=   112/   200 | beta=1.000e+00 | loss=  282.7603285 | loss_reconstruction=  275.7595372 | loss_kl=    7.0007923
#
# epoch=   113/   200 | beta=1.000e+00 | loss=  282.7184533 | loss_reconstruction=  275.7084423 | loss_kl=    7.0100096
#
# epoch=   114/   200 | beta=1.000e+00 | loss=  282.7218335 | loss_reconstruction=  275.7298177 | loss_kl=    6.9920188
#
# epoch=   115/   200 | beta=1.000e+00 | loss=  282.6109539 | loss_reconstruction=  275.5790990 | loss_kl=    7.0318567
#
# epoch=   116/   200 | beta=1.000e+00 | loss=  282.5498852 | loss_reconstruction=  275.5105260 | loss_kl=    7.0393588
#
# epoch=   117/   200 | beta=1.000e+00 | loss=  282.5140101 | loss_reconstruction=  275.4563755 | loss_kl=    7.0576350
#
# epoch=   118/   200 | beta=1.000e+00 | loss=  282.4420607 | loss_reconstruction=  275.3752933 | loss_kl=    7.0667686
#
# epoch=   119/   200 | beta=1.000e+00 | loss=  282.3434067 | loss_reconstruction=  275.1985423 | loss_kl=    7.1448633
#
# epoch=   120/   200 | beta=1.000e+00 | loss=  282.2881944 | loss_reconstruction=  275.2264116 | loss_kl=    7.0617834
#
# epoch=   121/   200 | beta=1.000e+00 | loss=  282.3327675 | loss_reconstruction=  275.1888593 | loss_kl=    7.1439066
#
# epoch=   122/   200 | beta=1.000e+00 | loss=  282.1974191 | loss_reconstruction=  275.0950402 | loss_kl=    7.1023774
#
# epoch=   123/   200 | beta=1.000e+00 | loss=  282.1634182 | loss_reconstruction=  275.0264452 | loss_kl=    7.1369720
#
# epoch=   124/   200 | beta=1.000e+00 | loss=  282.0741365 | loss_reconstruction=  274.9359881 | loss_kl=    7.1381496
#
# epoch=   125/   200 | beta=1.000e+00 | loss=  282.0035023 | loss_reconstruction=  274.8549673 | loss_kl=    7.1485385
#
# epoch=   126/   200 | beta=1.000e+00 | loss=  281.9264086 | loss_reconstruction=  274.7641415 | loss_kl=    7.1622653
#
# epoch=   127/   200 | beta=1.000e+00 | loss=  282.0020082 | loss_reconstruction=  274.8529176 | loss_kl=    7.1490886
#
# epoch=   128/   200 | beta=1.000e+00 | loss=  281.8712930 | loss_reconstruction=  274.6767646 | loss_kl=    7.1945297
#
# epoch=   129/   200 | beta=1.000e+00 | loss=  281.9143723 | loss_reconstruction=  274.7311584 | loss_kl=    7.1832164
#
# epoch=   130/   200 | beta=1.000e+00 | loss=  281.7123773 | loss_reconstruction=  274.4968872 | loss_kl=    7.2154878
#
# epoch=   131/   200 | beta=1.000e+00 | loss=  281.8149554 | loss_reconstruction=  274.5902528 | loss_kl=    7.2247039
#
# epoch=   132/   200 | beta=1.000e+00 | loss=  281.7184181 | loss_reconstruction=  274.4734438 | loss_kl=    7.2449768
#
# epoch=   133/   200 | beta=1.000e+00 | loss=  281.6390576 | loss_reconstruction=  274.3815558 | loss_kl=    7.2575029
#
# epoch=   134/   200 | beta=1.000e+00 | loss=  281.5425682 | loss_reconstruction=  274.2619722 | loss_kl=    7.2805924
#
# epoch=   135/   200 | beta=1.000e+00 | loss=  281.5927777 | loss_reconstruction=  274.3164444 | loss_kl=    7.2763353
#
# epoch=   136/   200 | beta=1.000e+00 | loss=  281.5891228 | loss_reconstruction=  274.3227386 | loss_kl=    7.2663843
#
# epoch=   137/   200 | beta=1.000e+00 | loss=  281.4647870 | loss_reconstruction=  274.1677225 | loss_kl=    7.2970634
#
# epoch=   138/   200 | beta=1.000e+00 | loss=  281.3876809 | loss_reconstruction=  274.0601400 | loss_kl=    7.3275409
#
# epoch=   139/   200 | beta=1.000e+00 | loss=  281.3117968 | loss_reconstruction=  273.9787403 | loss_kl=    7.3330570
#
# epoch=   140/   200 | beta=1.000e+00 | loss=  281.3007469 | loss_reconstruction=  273.9542660 | loss_kl=    7.3464801
#
# epoch=   141/   200 | beta=1.000e+00 | loss=  281.1552578 | loss_reconstruction=  273.8355552 | loss_kl=    7.3197034
#
# epoch=   142/   200 | beta=1.000e+00 | loss=  281.1886482 | loss_reconstruction=  273.8266686 | loss_kl=    7.3619788
#
# epoch=   143/   200 | beta=1.000e+00 | loss=  281.0172310 | loss_reconstruction=  273.6603771 | loss_kl=    7.3568535
#
# epoch=   144/   200 | beta=1.000e+00 | loss=  281.0468818 | loss_reconstruction=  273.6759461 | loss_kl=    7.3709337
#
# epoch=   145/   200 | beta=1.000e+00 | loss=  281.0145840 | loss_reconstruction=  273.6349589 | loss_kl=    7.3796230
#
# epoch=   146/   200 | beta=1.000e+00 | loss=  280.9145588 | loss_reconstruction=  273.5015335 | loss_kl=    7.4130242
#
# epoch=   147/   200 | beta=1.000e+00 | loss=  280.8522958 | loss_reconstruction=  273.4309358 | loss_kl=    7.4213610
#
# epoch=   148/   200 | beta=1.000e+00 | loss=  280.7992032 | loss_reconstruction=  273.3811607 | loss_kl=    7.4180439
#
# epoch=   149/   200 | beta=1.000e+00 | loss=  280.7539232 | loss_reconstruction=  273.2961341 | loss_kl=    7.4577885
#
# epoch=   150/   200 | beta=1.000e+00 | loss=  280.6985872 | loss_reconstruction=  273.2780033 | loss_kl=    7.4205844
#
# epoch=   151/   200 | beta=1.000e+00 | loss=  280.5960236 | loss_reconstruction=  273.1460194 | loss_kl=    7.4500072
#
# epoch=   152/   200 | beta=1.000e+00 | loss=  280.6348479 | loss_reconstruction=  273.1616987 | loss_kl=    7.4731490
#
# epoch=   153/   200 | beta=1.000e+00 | loss=  280.6081348 | loss_reconstruction=  273.1333864 | loss_kl=    7.4747486
#
# epoch=   154/   200 | beta=1.000e+00 | loss=  280.5169576 | loss_reconstruction=  273.0277998 | loss_kl=    7.4891575
#
# epoch=   155/   200 | beta=1.000e+00 | loss=  280.4615470 | loss_reconstruction=  272.9669351 | loss_kl=    7.4946112
#
# epoch=   156/   200 | beta=1.000e+00 | loss=  280.4402686 | loss_reconstruction=  272.9294158 | loss_kl=    7.5108515
#
# epoch=   157/   200 | beta=1.000e+00 | loss=  280.3578470 | loss_reconstruction=  272.8545952 | loss_kl=    7.5032507
#
# epoch=   158/   200 | beta=1.000e+00 | loss=  280.3543922 | loss_reconstruction=  272.7896372 | loss_kl=    7.5647534
#
# epoch=   159/   200 | beta=1.000e+00 | loss=  280.2938377 | loss_reconstruction=  272.7559641 | loss_kl=    7.5378742
#
# epoch=   160/   200 | beta=1.000e+00 | loss=  280.2332789 | loss_reconstruction=  272.6733907 | loss_kl=    7.5598897
#
# epoch=   161/   200 | beta=1.000e+00 | loss=  280.2099147 | loss_reconstruction=  272.6821874 | loss_kl=    7.5277279
#
# epoch=   162/   200 | beta=1.000e+00 | loss=  280.1914342 | loss_reconstruction=  272.6225755 | loss_kl=    7.5688561
#
# epoch=   163/   200 | beta=1.000e+00 | loss=  280.1466955 | loss_reconstruction=  272.5703867 | loss_kl=    7.5763059
#
# epoch=   164/   200 | beta=1.000e+00 | loss=  280.0752059 | loss_reconstruction=  272.5213568 | loss_kl=    7.5538486
#
# epoch=   165/   200 | beta=1.000e+00 | loss=  280.0082109 | loss_reconstruction=  272.4273499 | loss_kl=    7.5808611
#
# epoch=   166/   200 | beta=1.000e+00 | loss=  280.0130026 | loss_reconstruction=  272.4101846 | loss_kl=    7.6028201
#
# epoch=   167/   200 | beta=1.000e+00 | loss=  279.9824939 | loss_reconstruction=  272.3828311 | loss_kl=    7.5996632
#
# epoch=   168/   200 | beta=1.000e+00 | loss=  279.9590713 | loss_reconstruction=  272.3635682 | loss_kl=    7.5955031
#
# epoch=   169/   200 | beta=1.000e+00 | loss=  279.8861745 | loss_reconstruction=  272.2713576 | loss_kl=    7.6148171
#
# epoch=   170/   200 | beta=1.000e+00 | loss=  279.8478266 | loss_reconstruction=  272.2116182 | loss_kl=    7.6362091
#
# epoch=   171/   200 | beta=1.000e+00 | loss=  279.8097373 | loss_reconstruction=  272.1700384 | loss_kl=    7.6397003
#
# epoch=   172/   200 | beta=1.000e+00 | loss=  279.8003023 | loss_reconstruction=  272.1626761 | loss_kl=    7.6376281
#
# epoch=   173/   200 | beta=1.000e+00 | loss=  279.7521464 | loss_reconstruction=  272.1092368 | loss_kl=    7.6429078
#
# epoch=   174/   200 | beta=1.000e+00 | loss=  279.7250142 | loss_reconstruction=  272.0656399 | loss_kl=    7.6593724
#
# epoch=   175/   200 | beta=1.000e+00 | loss=  279.6885206 | loss_reconstruction=  272.0532667 | loss_kl=    7.6352558
#
# epoch=   176/   200 | beta=1.000e+00 | loss=  279.6731122 | loss_reconstruction=  272.0236931 | loss_kl=    7.6494174
#
# epoch=   177/   200 | beta=1.000e+00 | loss=  279.6598286 | loss_reconstruction=  271.9986242 | loss_kl=    7.6612085
#
# epoch=   178/   200 | beta=1.000e+00 | loss=  279.6656973 | loss_reconstruction=  271.9897215 | loss_kl=    7.6759761
#
# epoch=   179/   200 | beta=1.000e+00 | loss=  279.5858540 | loss_reconstruction=  271.8616087 | loss_kl=    7.7242471
#
# epoch=   180/   200 | beta=1.000e+00 | loss=  279.5600917 | loss_reconstruction=  271.8846160 | loss_kl=    7.6754764
#
# epoch=   181/   200 | beta=1.000e+00 | loss=  279.5452304 | loss_reconstruction=  271.8738895 | loss_kl=    7.6713400
#
# epoch=   182/   200 | beta=1.000e+00 | loss=  279.5102094 | loss_reconstruction=  271.8140581 | loss_kl=    7.6961513
#
# epoch=   183/   200 | beta=1.000e+00 | loss=  279.5265312 | loss_reconstruction=  271.8400120 | loss_kl=    7.6865191
#
# epoch=   184/   200 | beta=1.000e+00 | loss=  279.4874263 | loss_reconstruction=  271.8099348 | loss_kl=    7.6774893
#
# epoch=   185/   200 | beta=1.000e+00 | loss=  279.4767986 | loss_reconstruction=  271.7851164 | loss_kl=    7.6916816
#
# epoch=   186/   200 | beta=1.000e+00 | loss=  279.4723405 | loss_reconstruction=  271.7518773 | loss_kl=    7.7204616
#
# epoch=   187/   200 | beta=1.000e+00 | loss=  279.4459559 | loss_reconstruction=  271.7208142 | loss_kl=    7.7251405
#
# epoch=   188/   200 | beta=1.000e+00 | loss=  279.4053023 | loss_reconstruction=  271.7015309 | loss_kl=    7.7037723
#
# epoch=   189/   200 | beta=1.000e+00 | loss=  279.4359665 | loss_reconstruction=  271.7674383 | loss_kl=    7.6685255
#
# epoch=   190/   200 | beta=1.000e+00 | loss=  279.4114634 | loss_reconstruction=  271.6726184 | loss_kl=    7.7388456
#
# epoch=   191/   200 | beta=1.000e+00 | loss=  279.4079577 | loss_reconstruction=  271.7146000 | loss_kl=    7.6933578
#
# epoch=   192/   200 | beta=1.000e+00 | loss=  279.3912595 | loss_reconstruction=  271.6800762 | loss_kl=    7.7111828
#
# epoch=   193/   200 | beta=1.000e+00 | loss=  279.3648580 | loss_reconstruction=  271.6886732 | loss_kl=    7.6761852
#
# epoch=   194/   200 | beta=1.000e+00 | loss=  279.3833584 | loss_reconstruction=  271.6655422 | loss_kl=    7.7178153
#
# epoch=   195/   200 | beta=1.000e+00 | loss=  279.3717486 | loss_reconstruction=  271.6826829 | loss_kl=    7.6890674
#
# epoch=   196/   200 | beta=1.000e+00 | loss=  279.3639658 | loss_reconstruction=  271.6607696 | loss_kl=    7.7031975
#
# epoch=   197/   200 | beta=1.000e+00 | loss=  279.3285255 | loss_reconstruction=  271.6507081 | loss_kl=    7.6778169
#
# epoch=   198/   200 | beta=1.000e+00 | loss=  279.3650241 | loss_reconstruction=  271.6418754 | loss_kl=    7.7231494
#
# epoch=   199/   200 | beta=1.000e+00 | loss=  279.3607763 | loss_reconstruction=  271.6859720 | loss_kl=    7.6748051
#
# epoch=   200/   200 | beta=1.000e+00 | loss=  279.3591440 | loss_reconstruction=  271.6240921 | loss_kl=    7.7350530

# %% [markdown]
# ## Call differential Etv2 motif centric V-plots between MEF and D7 MEF by SeATAC

# %% [markdown]
# ### Extract motif centric regions

# %%
data('homer_pwms') # 321 TF motifs from Homer database

# %%
j <- 82 # Etv2
homer_pwms[j]
# Out:
# PWMatrixList of length 1
# names(1): Etv2(ETS)/ES-ER71-ChIP-Seq(GSE59402)/Homer(0.967)

# %%
gr <- matchMotifs(homer_pwms[j], gr0, genome = BSgenome.Mmusculus.UCSC.mm10, out = 'positions')[[1]] %>%
  resize(width = ARGS[['block_size']], fix = 'center')

# %%
sprintf('number of motif-centric regions: %s', length(gr)) %>% message()
# Out:
# number of motif-centric regions: 24935

# %% [markdown]
# ### Read V-plots

# %%
x <- read_vplot(gr, filenames = local_bam_files, genome = BSgenome.Mmusculus.UCSC.mm10, bin_size = ARGS[['bin_size']], fragment_size_range = c(0, ARGS[['fragment_size_range_max']]), fragment_size_interval = ARGS[['fragment_size_interval']])
# Out:
# read_bam | reading ./s3.msi.umn.edu/gongx030/datasets/dataset=Etv2ATAC_version=20190228b/EB_NoDox_D25.bam
#
# read_bam | reading ./s3.msi.umn.edu/gongx030/datasets/dataset=Etv2ATAC_version=20190228b/EB_Dox_D25_Flk1pos.bam

# %% [markdown]
# ### Get the latent representations of the V-plots

# %%
x <- model %>% predict(x, batch_size = ARGS[['vae_batch_size']], vplots = TRUE)

# %% [markdown]
# #Read the regions for Vplots

# %%
remote_res <- c(res = 'https://s3.msi.umn.edu/dsouz072/projects/seatac_project/config/seatac_EB_Etv2/Flk1pos_Up_EB_regions.rds')
for (f in remote_res){
  system(sprintf('wget -cx %s', f))
}
res <- gsub('https://', './', remote_res)

# %%
res <- readRDS(res[['res']])

# %%
sprintf('number of motif-centric regions: %s', length(res)) %>% message()
# Out:
# number of motif-centric regions: 24935

# %%
is_signif <- res$padj < 0.05
sprintf('# of significantly differential V-plots called by SeATAC: %d', sum(is_signif)) %>% message()
# Out:
# # of significantly differential V-plots called by SeATAC: 6275

# %% [markdown]
# #SeATAC Only

# %%
only_seatac <- res$padj < 0.05 & res$log_ratio < -ARGS[['log_ratio_cutoff']] & !res$macs2 > -log10(ARGS[['padjusted_cutoff']]) & !res$difference < -0.4 
sprintf('# of Vplots that have increased nuclsoeome occupancy at the center for undifferentiated EBs: %d', sum(only_seatac)) %>% message()
# Out:
# # of Vplots that have increased nuclsoeome occupancy at the center for undifferentiated EBs: 1626

# %%
x2 <- model %>% predict(x[only_seatac], batch_size = ARGS[['vae_batch_size']], vplots = TRUE)
p1 <- vplot(x2, 'counts', ncol = 2L) +ggtitle('counts                                        SeATAC only') 
p2 <- vplot(x2, 'predicted_counts', ncol = 2L)

# %% [markdown]
# # MACs2 Only

# %%
seatac_macs2 <- !(res$padj < 0.05 & res$log_ratio < -ARGS[['log_ratio_cutoff']]) & res$macs2 > -log10(ARGS[['padjusted_cutoff']]) & !(res$difference < -0.4 & res$flk1pos == TRUE)
sprintf('# of Vplots that have increased nuclsoeome occupancy at the center for undifferentiated EBs and summits called by MACS2 in Flk1+ EBs at D2.5 post Etv2 induction: %d', sum(seatac_macs2)) %>% message()
# Out:
# # of Vplots that have increased nuclsoeome occupancy at the center for undifferentiated EBs and summits called by MACS2 in Flk1+ EBs at D2.5 post Etv2 induction: 222

# %%
x3 <- model %>% predict(x[seatac_macs2], batch_size = ARGS[['vae_batch_size']], vplots = TRUE)
p3 <- vplot(x3, 'counts', ncol = 2L) + ggtitle('counts                                  SeATAC & MACS2') 
p4 <- vplot(x3, 'predicted_counts', ncol = 2L)

# %% [markdown]
# #NucleoATAC Only

# %%
seatac_nucleoatac <- !(res$padj < 0.05 & res$log_ratio < -ARGS[['log_ratio_cutoff']]) & !res$macs2 > -log10(ARGS[['padjusted_cutoff']]) &  res$difference < -0.4 
sprintf('# of Vplots that have increased nuclsoeome occupancy at the center and regions from NucleoATAC with increased nucleosome occupance for undifferentiated EBs : %d', sum(seatac_nucleoatac)) %>% message()
# Out:
# # of Vplots that have increased nuclsoeome occupancy at the center and regions from NucleoATAC with increased nucleosome occupance for undifferentiated EBs : 2305

# %%
x4 <- model %>% predict(x[seatac_nucleoatac], batch_size = ARGS[['vae_batch_size']], vplots = TRUE)
p5 <- vplot(x4, 'counts', ncol = 2L) + ggtitle('counts                                  SeATAC & NucleoATAC') 
p6 <- vplot(x4, 'predicted_counts', ncol = 2L)

# %% [markdown]
# # Vplots for EBs

# %%
options(repr.plot.width = 8, repr.plot.height = 18)
p1 / p2 / p3/ p4 / p5 / p6 + plot_annotation(tag_levels = 'A')
# Out:
# Warning message:
# “Removed 64 rows containing missing values (geom_raster).”
# Warning message:
# “Removed 64 rows containing missing values (geom_raster).”
# Warning message:
# “Removed 64 rows containing missing values (geom_raster).”
# Warning message:
# “Removed 64 rows containing missing values (geom_raster).”
# Warning message:
# “Removed 64 rows containing missing values (geom_raster).”
# Warning message:
# “Removed 64 rows containing missing values (geom_raster).”
# plot without title

# %% [markdown]
# ## SessionInfo

# %%
sessionInfo()
# Out:
# R version 4.1.2 (2021-11-01)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 18.04.5 LTS
#
# Matrix products: default
# BLAS:   /usr/lib/x86_64-linux-gnu/openblas/libblas.so.3
# LAPACK: /usr/lib/x86_64-linux-gnu/libopenblasp-r0.2.20.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] grid      stats4    stats     graphics  grDevices utils     datasets
# [8] methods   base
#
# other attached packages:
#  [1] patchwork_1.1.1                    ggplot2_3.3.5
#  [3] VennDiagram_1.7.1                  futile.logger_1.4.3
#  [5] igraph_1.2.11                      chromVARmotifs_0.2.0
#  [7] motifmatchr_1.16.0                 dplyr_1.0.8
#  [9] BSgenome.Mmusculus.UCSC.mm10_1.4.3 BSgenome_1.62.0
# [11] rtracklayer_1.54.0                 Biostrings_2.62.0
# [13] XVector_0.34.0                     seatac_0.4.0006
# [15] SummarizedExperiment_1.24.0        Biobase_2.54.0
# [17] MatrixGenerics_1.6.0               matrixStats_0.61.0
# [19] GenomicRanges_1.46.1               GenomeInfoDb_1.30.1
# [21] IRanges_2.28.0                     S4Vectors_0.32.3
# [23] BiocGenerics_0.40.0                tfdatasets_2.7.0
# [25] tfprobability_0.15.0               tensorflow_2.8.0
# [27] devtools_2.4.3                     usethis_2.1.5
#
# loaded via a namespace (and not attached):
#   [1] uuid_1.0-3                  backports_1.4.1
#   [3] plyr_1.8.6                  repr_1.1.4
#   [5] BiocParallel_1.28.3         tfruns_1.5.0
#   [7] TFBSTools_1.32.0            digest_0.6.29
#   [9] htmltools_0.5.2             GO.db_3.14.0
#  [11] fansi_1.0.2                 magrittr_2.0.2
#  [13] memoise_2.0.1               tzdb_0.2.0
#  [15] remotes_2.4.2               readr_2.1.2
#  [17] annotate_1.72.0             R.utils_2.11.0
#  [19] prettyunits_1.1.1           colorspace_2.0-3
#  [21] blob_1.2.2                  rappdirs_0.3.3
#  [23] callr_3.7.0                 crayon_1.5.0
#  [25] RCurl_1.98-1.6              jsonlite_1.8.0
#  [27] TFMPvalue_0.0.8             zeallot_0.1.0
#  [29] glue_1.6.2                  gtable_0.3.0
#  [31] zlibbioc_1.40.0             DelayedArray_0.20.0
#  [33] pkgbuild_1.3.1              abind_1.4-5
#  [35] scales_1.1.1                futile.options_1.0.1
#  [37] DBI_1.1.2                   Rcpp_1.0.8
#  [39] xtable_1.8-4                reticulate_1.24
#  [41] bit_4.0.4                   httr_1.4.2
#  [43] gplots_3.1.1                ellipsis_0.3.2
#  [45] farver_2.1.0                pkgconfig_2.0.3
#  [47] XML_3.99-0.9                R.methodsS3_1.8.1
#  [49] utf8_1.2.2                  here_1.0.1
#  [51] labeling_0.4.2              tidyselect_1.1.2
#  [53] rlang_1.0.1                 reshape2_1.4.4
#  [55] AnnotationDbi_1.56.2        munsell_0.5.0
#  [57] tools_4.1.2                 cachem_1.0.6
#  [59] cli_3.2.0                   DirichletMultinomial_1.36.0
#  [61] generics_0.1.2              RSQLite_2.2.10
#  [63] evaluate_0.15               stringr_1.4.0
#  [65] fastmap_1.1.0               yaml_2.3.5
#  [67] processx_3.5.2              bit64_4.0.5
#  [69] fs_1.5.2                    caTools_1.18.2
#  [71] purrr_0.3.4                 KEGGREST_1.34.0
#  [73] whisker_0.4                 formatR_1.11
#  [75] R.oo_1.24.0                 poweRlaw_0.70.6
#  [77] pracma_2.3.8                brio_1.1.3
#  [79] compiler_4.1.2              curl_4.3.2
#  [81] png_0.1-7                   testthat_3.1.2
#  [83] tibble_3.1.6                stringi_1.7.6
#  [85] ps_1.6.0                    desc_1.4.0
#  [87] lattice_0.20-45             IRdisplay_1.1
#  [89] CNEr_1.30.0                 Matrix_1.4-0
#  [91] keras_2.8.0                 vctrs_0.3.8
#  [93] pillar_1.7.0                lifecycle_1.0.1
#  [95] tfautograph_0.3.2           BiocManager_1.30.16
#  [97] bitops_1.0-7                R6_2.5.1
#  [99] BiocIO_1.4.0                KernSmooth_2.23-20
# [101] sessioninfo_1.2.2           lambda.r_1.2.4
# [103] gtools_3.9.2                assertthat_0.2.1
# [105] seqLogo_1.60.0              pkgload_1.2.4
# [107] rprojroot_2.0.2             rjson_0.2.21
# [109] withr_2.4.3                 GenomicAlignments_1.30.0
# [111] Rsamtools_2.10.0            GenomeInfoDbData_1.2.7
# [113] parallel_4.1.2              hms_1.1.1
# [115] IRkernel_1.3                pbdZMQ_0.3-7
# [117] base64enc_0.1-3             restfulr_0.0.13

# %%
Sys.time() - start_time
# Out:
# Time difference of 49.17502 mins

# %%
dsouz072/projects/seatac_project/config/seatac_MEF_Etv2/Flk1pos_up_MEF_regions.rds
dsouz072/projects/seatac_project/config/seatac_MEF_Etv2/Flk1pos_down_MEF_regions.rds
dsouz072/projects/seatac_project/config/seatac_EB_Etv2/Flk1pos_down_EB_regions.rds
dsouz072/projects/seatac_project/config/seatac_EB_Etv2/Flk1pos_Up_EB_regions.rds
